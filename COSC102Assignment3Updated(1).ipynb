# %% [markdown]
# #                                  COSC102 Group Assignment 3
# # Machine Learning Portfolio
#
# # Group Members - Will Duckworth, Jim Purvis, David Anderson
#
# # KNN Classifier, RandomForest Classifier, SGD Classifier, Neural Network

# %% [markdown]
# # Import necessary libraries

# %%
# If tensorflow and mlxtend are not already installed, uncomment and run this cell
# !pip install tensorflow
# !pip install mlxtend
# Out:
# Requirement already satisfied: tensorflow in c:\users\wills\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: packaging in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\wills\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\wills\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wills\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wills\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\wills\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\wills\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\wills\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wills\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: mlxtend in c:\users\wills\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (61.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wills\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\wills\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wills\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)

# %%
import csv
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import math
import statistics
from sklearn import preprocessing, metrics
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn import neighbors
from sklearn.metrics import plot_confusion_matrix as plot_cm
from mlxtend.plotting import plot_confusion_matrix as plot_nn_cm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.utils.np_utils import to_categorical
import tensorflow as tf

# %% [markdown]
# # *** Data Preparation ***

# %% [markdown]
# ## Set the file paths for the 2 data sets to be read
# ## Convert the data to a Pandas DataFrame

# %%
imu_data_path = os.path.abspath("a3_imu_data.csv")

annotations_path = os.path.abspath("a3_activity_annotations.csv")

imu_data = pd.read_csv(imu_data_path, delimiter=",")

imu_data_frame = pd.DataFrame(data=imu_data)

annotations_data = pd.read_csv(annotations_path, delimiter=",")

annotations_data_frame = pd.DataFrame(data=annotations_data)


annotations_data_frame.head()
# Out:
#                  image        xmin        ymin        xmax        ymax  \
# 0         a3.mp4#t=0.0  868.943127  417.331032  919.139168  557.535077
# 1        a3.mp4#t=66.2  854.251592  330.392238  926.484935  564.882015
# 2        a3.mp4#t=75.4  855.475924  324.882034  929.545709  561.820810
# 3  a3.mp4#t=139.333333  849.966598  321.208565  928.933599  563.045281
# 4  a3.mp4#t=146.733333  855.475924  327.331004  935.667145  553.249400
#
#       label
# 0   Walking
# 1  Standing
# 2   Walking
# 3  Standing
# 4   Jogging

# %% [markdown]
# ## Create empty lists to store the separated data for each of the activity set data points

# %%
time_track = []
ax_set = []
ay_set = []
az_set = []

gx_set = []
gy_set = []
gz_set = []

activity_set = []

# %% [markdown]
# ## Create function to map the activity type and return an integer value for that activity

# %%
def map_activity(activity_string):
    if activity_string == 'Standing':
        return 0
    elif activity_string == 'Walking':
        return 1
    elif activity_string == 'Jogging':
        return 2
    elif activity_string == 'Side-Step':
        return 3
    elif activity_string == 'Running':
        return 4

# %% [markdown]
# ## Read in the data as a CSV, and append the lists depending on the label

# %%
with open(imu_data_path, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        time_track.append(float(row[0]))
        ax_set.append(float(row[1]))
        ay_set.append(float(row[2]))
        az_set.append(float(row[3]))
        gx_set.append(float(row[4]))
        gy_set.append(float(row[5]))
        gz_set.append(float(row[6]))

# %% [markdown]
# ## Create a color list to visualise the data from the plot

# %%
fig, axs = plt.subplots(2,1,figsize=(20,10))
axs[0].plot(ax_set, color='r')
axs[0].plot(ay_set, color='g')
axs[0].plot(az_set, color='b')

axs[1].plot(gx_set, color='r')
axs[1].plot(gy_set, color='g')
axs[1].plot(gz_set, color='b')

# %% [markdown]
# ## Cut the data to the starting point of the activity, removing prior noise and sync the data to the video

# %%
start_idx = 825

fig, axs = plt.subplots(2,1,figsize=(20,10))
axs[0].plot(ax_set[start_idx:370000], color='r')
axs[0].plot(ay_set[start_idx:370000], color='g')
axs[0].plot(az_set[start_idx:370000], color='b')

axs[1].plot(gx_set[start_idx:370000], color='r')
axs[1].plot(gy_set[start_idx:370000], color='g')
axs[1].plot(gz_set[start_idx:370000], color='b')

# %% [markdown]
# ## Find the end point of the video and cut the unnecessary end noise

# %%
#Now we need to find the end point
start_ts = time_track[start_idx]
print(start_ts)

# The video has been cut to 443 seconds in length - need to find 
# Start_ts + 443 seconds. This should land us at the end point
# We can sanity check this by inspecting the plot

end_idx = time_track.index(start_ts+711)

# Sanity Check
fig, axs = plt.subplots(2,1,figsize=(20,10))
axs[0].plot(ax_set[start_idx:end_idx], color='r')
axs[0].plot(ay_set[start_idx:end_idx], color='g')
axs[0].plot(az_set[start_idx:end_idx], color='b')

axs[1].plot(gx_set[start_idx:end_idx], color='r')
axs[1].plot(gy_set[start_idx:end_idx], color='g')
axs[1].plot(gz_set[start_idx:end_idx], color='b')
# Out:
# 1598240221.0

# %% [markdown]
# ## Read in the annotations file data as CSV, iterate through the data and separate to get the time stamp

# %%
with open(annotations_path, newline='') as f:
    reader = csv.reader(f)
    next(reader, None)  # skip the headers
    for row in reader:
        time_Stamp = (row[0].split('='))[1]
        activity_set.append([float(time_Stamp),row[-1], map_activity(row[-1])])

# %% [markdown]
# ## Cut the data from the activity set, and find the vertical line of best fit to separate the points

# %%
# Now we can create an activity time track for each data point within
# the imu timeseries. We will have a list to store the numeric code and the string.
activity_timeseries = []
activity_string_timeseries = []
activity_idx = 0

# We need the time stamp for the start point
start_time = time_track[start_idx]

# The time track segment we are interested in 
time_track_segment = time_track[start_idx:end_idx]

#Add an 'end' activity - this book-ends the data
activity_set.append([time_track_segment[-1]-start_time, 'Standing'])

# Zero out the time track segment to make it match the video time
time_track_segment = np.array(time_track_segment)-start_time

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(time_track_segment,ax_set[start_idx:end_idx], color='r')
ax.plot(time_track_segment,ay_set[start_idx:end_idx], color='g')
ax.plot(time_track_segment,az_set[start_idx:end_idx], color='b')

for act in np.array(list(zip(*activity_set)))[0,:]:
    ax.axvline(float(act))

# %% [markdown]
# ## Plot the end time steps to check the data

# %%
for imu_time_track_item in time_track_segment:
    current_time =  imu_time_track_item
    next_activity_ts = activity_set[activity_idx+1][0]
    
    # Here we need to move to the next activity in the annotations data if the current
    # IMU data point lies after the next annotation time stamp.
    if current_time > next_activity_ts:
        #Move to nex activity
        activity_idx = activity_idx + 1
        next_activity_ts = activity_set[activity_idx+1][0]
    
    
    activity_timeseries.append(activity_set[activity_idx][2])
    activity_string_timeseries.append(activity_set[activity_idx][1])

# %% [markdown]
# ## Plot a histogram to visualise the distribution

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.xlabel("Activity"), plt.ylabel("TimeStep"), plt.legend(["Distribution"], loc="upper right", )
ax.hist(activity_timeseries,bins=[-0.5,0.5,1.5,2.5,3.5,4.5], histtype='stepfilled', align='right')
plt.show()

# %% [markdown]
# ## Set the x, y, z sets to the range of start to finish data

# %%
#We are only interested in the video window
ax_set = ax_set[start_idx:end_idx]
ay_set = ay_set[start_idx:end_idx]
az_set = az_set[start_idx:end_idx]
gx_set = gx_set[start_idx:end_idx]
gy_set = gy_set[start_idx:end_idx]
gz_set = gz_set[start_idx:end_idx]

# %% [markdown]
# ## Calculate the Signal Magnitude Area, and the Average Intensity for each label.
# ## Store the data into features, a target set for the training and testing data based on a 1 second interval from the video window

# %%
feature_set = []
target_set  = []            
window_size = 1.0

for t in range(int(time_track_segment[0]),int(time_track_segment[-1])):
    if not t+window_size in time_track_segment or not t in time_track_segment:
        continue
        
    

    #The index function finds the index of the first occurrence of the data
    window_start_idx = list(time_track_segment).index(t)
    window_end_idx = list(time_track_segment).index(t+window_size)
    ax_window = ax_set[window_start_idx:window_end_idx]
    ay_window = ay_set[window_start_idx:window_end_idx]
    az_window = az_set[window_start_idx:window_end_idx]
    gx_window = gx_set[window_start_idx:window_end_idx]
    gy_window = gy_set[window_start_idx:window_end_idx]
    gz_window = gz_set[window_start_idx:window_end_idx]

    #activity that will be assigned to the set of features
    activity_code = activity_timeseries[window_start_idx]
    
    # Now we can build features from the data window
    # Mean
    mu_ax, mu_ay, mu_az = statistics.mean(ax_window), statistics.mean(ay_window), statistics.mean(az_window)
    mu_gx, mu_gy, mu_gz = statistics.mean(gx_window), statistics.mean(gy_window), statistics.mean(gz_window)

    # Max
    max_ax, max_ay, max_az = max(ax_window), max(ay_window), max(az_window)
    max_gx, max_gy, max_gz = max(gx_window), max(gy_window), max(gz_window)

    # Min
    min_ax, min_ay, min_az = min(ax_window), min(ay_window), min(az_window)
    min_gx, min_gy, min_gz = min(gx_window), min(gy_window), min(gz_window)

    # Sum
    ax_abs_sum, ay_abs_sum, az_abs_sum = 0, 0, 0
    gx_abs_sum, gy_abs_sum, gz_abs_sum = 0, 0, 0

    # Sum of sqrt
    a_sum_sq = 0
    g_sum_sq = 0
    
        
    for i in range(0, len(ax_window)):

        # Add up the absolute values for the SMA
        ax_abs_sum = ax_abs_sum + abs(ax_window[i])
        ay_abs_sum = ay_abs_sum + abs(ay_window[i])
        az_abs_sum = az_abs_sum + abs(az_window[i])

        gx_abs_sum = gx_abs_sum + abs(gx_window[i])
        gy_abs_sum = gy_abs_sum + abs(gy_window[i])
        gz_abs_sum = gz_abs_sum + abs(gz_window[i])


        a_sum_sq = ((ax_window[i]**2) + (ay_window[i]**2) + (az_window[i]**2)) + a_sum_sq
        g_sum_sq = ((gx_window[i]**2) + (gy_window[i]**2) + (gz_window[i]**2)) + g_sum_sq

    # Signal Magnitude area    
    a_sma = (ax_abs_sum + ay_abs_sum + az_abs_sum) / len(ax_window)
    g_sma = (gx_abs_sum + gy_abs_sum + gz_abs_sum) / len(ax_window)

    # Average intensity
    a_av_intensity = math.sqrt(a_sum_sq) / len(ax_window)
    g_av_intensity = math.sqrt(g_sum_sq) / len(ax_window)


    feature_row = [mu_ax, mu_ay, mu_az, mu_gx, mu_gy, mu_gz,
                   max_ax, max_ay, max_az, max_gx, max_gy, max_gz,
                   min_ax, min_ay, min_az, min_gx, min_gy, min_gz,
                   a_sma, g_sma, a_av_intensity, g_av_intensity]

    feature_set.append(feature_row)
    target_set.append(activity_code)

# %% [markdown]
# ## Visualise the data

# %%
# Lets visualise some of the features just out of interest - we will look at the SMA and AI

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(range(1,705),np.array(feature_set)[:,18], color='r')
ax.plot(range(1,705),np.array(feature_set)[:,19], color='g')
ax.plot(range(1,705),np.array(feature_set)[:,20], color='b')
ax.plot(range(1,705),np.array(feature_set)[:,21], color='c')

# Plot the location of the activity transitions just to sanity check the data
#for act in np.array(list(zip(*activity_set)))[0,:]:
#    ax.axvline(float(act), alpha=0.5)

# REMOVED ACTIVITY SEGMENT LINES, DONT LINE UP PROPERLY

# %% [markdown]
# # *** Helper functions ***

# %% [markdown]
# ## Create a re-usable function to plot ROC Curves for each of the classifiers

# %%
def plot_roc_curve(function=None):
        nclasses = 3
        classifier = function
        x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=.2)
        classifier.fit(x_test, y_test)
        y_score = classifier.predict_proba(x_test)
        y_test_bin = preprocessing.label_binarize(y_test, classes=[0, 1, 2, 3, 4])
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(nclasses):
            fpr[i], tpr[i], _ = metrics.roc_curve(y_test_bin[:, i], y_score[:, i])
            roc_auc[i] = metrics.auc(fpr[i], tpr[i])
        fig, ax = plt.subplots(figsize=(5, 5))
        colors = ['cyan', 'magenta', 'purple', 'blue', 'pink']
        plt.plot([0,1], [0,1], "r--")
        for i, color in zip(range(nclasses), colors):
            plt.plot(fpr[i], tpr[i], color=color,
                     label='ROC curve of class {0} (area = {1:0.2f})'
                           ''.format(i, roc_auc[i]))
        ax.set_xlabel("False Positives")
        ax.set_ylabel("True Positives")
        ax.set_title("ROC Curve of Classifications")
        ax.legend(["y=x", "Walking", "Standing", "Running", "Side-Step", "Jogging"])
        plt.show()

# %% [markdown]
# ## Create a function to find the best test and train split for the data

# %%
classifiers = ["Standing", "Walking", "Jogging", "Side-Step", "Running"]

c_names = [[i] for i in classifiers]

# Feature names for the tree.
labels = ["Mean Ax", "Mean Ay", "Mean Az","Mean Gx", "Mean Gy", "Mean Gz",
           "Max Ax", "Max Ay", "Max Az","Max Gx", "Max Gy", "Max Gz", 
           "Min Ax", "Min Ay", "Min Az","Min Gx", "Min Gy", "Min Gz",
           "Acceleration SMA", "Gyroscope SMA" , "Acceleration AI", "Gyroscope AI"]

f_names = [[i] for i in labels]
        
        
def get_training_split():
    test_sizes = [round(float(i * .1), 2) for i in range(1, 9)].__reversed__()
    test_sizes = list(test_sizes)
    knn = neighbors.KNeighborsClassifier(n_neighbors=4)
    plt.figure()

    for test_size in test_sizes:
        scores = []
        for i in range(1, 100):
            x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=1 - test_size)
            knn.fit(x_train, y_train)
            scores.append(knn.score(x_test, y_test))
        plt.plot(test_size, np.mean(scores), "r+")
    plt.plot()
    plt.xlabel("training % split")
    plt.ylabel("predictions")
    plt.show()

# %% [markdown]
# # *** KNN Classifier ***

# %% [markdown]
# ## Create a function to find the best neighbors for the KNN Classifier

# %%
def find_knn_neighbours():
    k_range = range(1,20)
    scores = []
    max_score = []
    for k in k_range:
        x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set)
        knn = neighbors.KNeighborsClassifier(n_neighbors=k)
        knn.fit(x_train, y_train)
        scores.append(knn.score(x_test, y_test))
        max_score.append([(knn.score(x_test, y_test)), k]) 
    plt.figure()
    plt.xlabel("k neighbours")
    plt.ylabel("predictions")
    plt.scatter(k_range, scores)
    plt.grid()
    plt.xticks([i for i in range(0, 35, 5)])
    plt.xlim([0, 30])
    plt.ylim([0, 1])
    plt.show()
    max_score = max(max_score[1])
    return max_score

# %% [markdown]
# ## Train and test the data based on the KNN Classifier and produce plots to visually inspect the performance

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=.2, random_state=42)

# Set the number neighbours to use in the classifier
n_neighbors = find_knn_neighbours()

# we create an instance of Neighbours Classifier and fit the data.
clf = neighbors.KNeighborsClassifier(n_neighbors, weights='uniform')

# Train the model
clf.fit(X_train, y_train)

# Return the predictions for the 3-Fold cross-validation
y_predicted = cross_val_predict(clf, X_train,y_train, cv=3)

# Return the predictions for the test set
y_test_predicted = clf.predict(X_test)

# Construct the confusion matrices
conf_mat_train = confusion_matrix(y_train, y_predicted)
conf_mat_test = confusion_matrix(y_test, y_test_predicted)

# store categorical accuracy for comparison to other models
knn_cat_accuracy = list(conf_mat_test.diagonal()/conf_mat_test.sum(axis=1))

# Print out the recall, precision and F1 scores
# There will be a value for each class
# CV Train
print("CV Train Recall:\t", recall_score(y_train,y_predicted,average=None))
print("CV Train Precision:\t",precision_score(y_train,y_predicted,average=None))
print("CV Train F1 Score:\t",f1_score(y_train,y_predicted,average=None))

# Test
print("Test Recall:\t\t",recall_score(y_test,y_test_predicted,average=None))
print("Test Precision:\t\t",precision_score(y_test,y_test_predicted,average=None))
print("Test F1 Score:\t\t",f1_score(y_test,y_test_predicted,average=None))

# Plot the confusion matrices
fig, ax = plt.subplots()
disp = plot_cm(clf, X_train, y_train,
                                 display_labels=['Walking','Jogging','Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

ax.set_title('3-Fold Training')

fig, ax = plt.subplots()
disp = plot_cm(clf, X_test, y_test,
                                 display_labels=['Walking', 'Jogging', 'Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
plot_roc_curve(clf)
# Out:
# CV Train Recall:	 [0.95833333 0.95364238 0.96226415 0.84444444 0.76923077]
# CV Train Precision:	 [0.80232558 0.90566038 0.90532544 0.96202532 1.        ]
# CV Train F1 Score:	 [0.87341772 0.92903226 0.93292683 0.89940828 0.86956522]
# Test Recall:		 [0.89473684 0.95555556 0.9        0.95833333 1.        ]
# Test Precision:		 [0.77272727 0.91489362 1.         1.         1.        ]
# Test F1 Score:		 [0.82926829 0.93478261 0.94736842 0.9787234  1.        ]
# C:\Users\wills\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\wills\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Create a function to get the best training split for the RandomForestClassifier

# %%
# def get_training_split_forrest():
#     test_sizes = [round(float(i * .1), 2) for i in range(1, 9)].__reversed__()
#     test_sizes = list(test_sizes)
#     clf = RandomForestClassifier()
#     plt.figure()

#     for test_size in test_sizes:
#         scores = []
#         for i in range(1, 100):
#             x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=1 - test_size)
#             clf.fit(x_train, y_train)
#             scores.append(clf.score(x_test, y_test))
#         plt.plot(test_size, np.mean(scores), "r+")
#     plt.plot()
#     plt.xlabel("training % split")
#     plt.ylabel("predictions")
#     plt.show()

# %matplotlib notebook
# get_training_split()
clf = De
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # *** Random Forest Classifier ***

# %% [markdown]
# ## Test and train the Random Forest Classifier and plot graphs to visualise the data

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=.2, random_state=42)

clf = RandomForestClassifier()

clf.fit(X_train, y_train)
# Return the predictions for the 3-Fold cross-validation
y_predicted = cross_val_predict(clf, X_train,y_train, cv=3)
# Return the predictions for the test set
y_test_predicted = clf.predict(X_test)
# Construct the confusion matrices
conf_mat_train = confusion_matrix(y_train, y_predicted)
conf_mat_test = confusion_matrix(y_test, y_test_predicted)

# store categorical accuracy for comparison to other models
rf_cat_accuracy = list(conf_mat_test.diagonal()/conf_mat_test.sum(axis=1))

# Print out the recall, precision and F1 scores
# There will be a value for each class
# CV Train
print("CV Train Recall:\t", recall_score(y_train,y_predicted,average=None))
print("CV Train Precision:\t",precision_score(y_train,y_predicted,average=None))
print("CV Train F1 Score:\t",f1_score(y_train,y_predicted,average=None))

# Test
print("Test Recall:\t\t",recall_score(y_test,y_test_predicted,average=None))
print("Test Precision:\t\t",precision_score(y_test,y_test_predicted,average=None))
print("Test F1 Score:\t\t",f1_score(y_test,y_test_predicted,average=None))

# Plot the confusion matrices using the pretty functions
fig, ax = plt.subplots()
disp = plot_cm(clf, X_train, y_train,
                                 display_labels=['Walking','Jogging','Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

ax.set_title('3-Fold Training')

fig, ax = plt.subplots()
disp = plot_cm(clf, X_test, y_test,
                                 display_labels=['Walking', 'Jogging', 'Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
# Out:
# CV Train Recall:	 [0.91666667 0.96688742 0.98113208 0.92222222 0.9010989 ]
# CV Train Precision:	 [0.88       0.90123457 0.975      0.98809524 1.        ]
# CV Train F1 Score:	 [0.89795918 0.93290735 0.97805643 0.95402299 0.94797688]
# Test Recall:		 [0.94736842 0.97777778 0.925      1.         1.        ]
# Test Precision:		 [0.9        0.93617021 1.         1.         1.        ]
# Test F1 Score:		 [0.92307692 0.95652174 0.96103896 1.         1.        ]
# <img src="data:image/png;base64,..." width="640">
# C:\Users\wills\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\wills\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # *** Stochastic Gradient Descent Classifier ***

# %% [markdown]
# ## Split and scale data

# %%
# split train and test sets
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, random_state=42)

# scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Train model and optimise hyper parameters through iteration

# %%
from sklearn.metrics import recall_score, precision_score

best_mean_f1 = 0
best_alpha = 0
best_max_iter = 0

alpha_test_values = [0.001,0.005,0.01,0.05]
max_iter_test_values = [100,250,500]

# Iterate through hyper parameter options
for alpha in alpha_test_values:
    for iterations in max_iter_test_values:

        # train classifier
        sgd = SGDClassifier(alpha=alpha, max_iter=iterations, random_state=42)
        sgd.fit(X_train_scaled, y_train)

        # predict using 3-fold cross validation
        y_train_predicted = cross_val_predict(sgd, X_train_scaled, y_train, cv=3)                # TODO: DO I NEED TO SPECIFY FEATURE COLUMNS HERE ??


        current_f1 = np.mean(f1_score(y_train, y_train_predicted, average=None))
        if current_f1 > best_mean_f1:
            best_mean_f1 = current_f1
            best_alpha = alpha
            best_max_iter = iterations
            best_sgd = sgd
            best_y_train_predicted = y_train_predicted


# predict using best SGD classifier
y_test_predicted = best_sgd.predict(X_test_scaled)

print("Hyper Parameter Combination")
print("Best alpha: ", best_alpha)
print("Best max_iter: ", best_max_iter, "\n")
print("CV Train Recall: \t\t", recall_score(y_train, best_y_train_predicted, average=None))
print("CV Train Precision: \t", precision_score(y_train, best_y_train_predicted, average=None))
print("CV Train F1: \t\t\t", f1_score(y_train, best_y_train_predicted, average=None))
print("Test Recall: \t\t\t", recall_score(y_test, y_test_predicted, average=None))
print("Test Precision: \t\t", precision_score(y_test, y_test_predicted, average=None))
print("Test F1: \t\t\t\t", f1_score(y_test, y_test_predicted, average=None))
# Out:
# Hyper Parameter Combination
# Best alpha:  0.01
# Best max_iter:  100
#
# CV Train Recall: 		 [0.92647059 0.95       0.98648649 0.90588235 0.88505747]
# CV Train Precision: 	 [0.92647059 0.9109589  0.94805195 0.95061728 0.97468354]
# CV Train F1: 			 [0.92647059 0.93006993 0.96688742 0.92771084 0.92771084]
# Test Recall: 			 [0.91304348 0.94642857 0.96078431 0.89655172 1.        ]
# Test Precision: 		 [0.91304348 0.92982456 0.94230769 1.         0.94444444]
# Test F1: 				 [0.91304348 0.9380531  0.95145631 0.94545455 0.97142857]

# %% [markdown]
# ## Plot Confusion Matrices

# %%
# plot confusion matrix for train set
fig, ax = plt.subplots()
ax.set_title("Train")
disp = plot_cm(best_sgd, X_train_scaled, y_train,
                             display_labels=["Standing", "Walking", "Jogging", "Side-Step", "Running"],
                             cmap=plt.cm.Blues, ax=ax)

# plot confusion matrix for test set
fig, ax = plt.subplots()
ax.set_title("Test")
disp = plot_cm(best_sgd, X_test_scaled, y_test,
                             display_labels=["Standing", "Walking", "Jogging", "Side-Step", "Running"],
                             cmap=plt.cm.Blues, ax=ax)

# Store categorical accuracy for comparison to other models
conf_mat_test = confusion_matrix(y_test, y_test_predicted)
sgd_cat_accuracy = list(conf_mat_test.diagonal()/conf_mat_test.sum(axis=1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\wills\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <img src="data:image/png;base64,..." width="640">
# C:\Users\wills\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # *** Neural Network ***

# %% [markdown]
# ## Split and scale data

# %%
# split train and test sets
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, random_state=42)

# convert to numpy arrays
X_train = np.asarray(X_train)
y_train = np.asarray(y_train)
X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

# apply MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# convert target classes to categorical array for neural network
y_train_cat_array = to_categorical(y_train, num_classes=5)
y_test_cat_array = to_categorical(y_test, num_classes=5)

# %% [markdown]
# ## Build and train NN model

# %%
# NN input layer size
input_size = len(X_test_scaled[0])
# set random state
tf.random.set_seed(42)
# declare variable for activation function to test various functions
activation_function = 'relu'

# build model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(input_size, activation=activation_function),
    tf.keras.layers.Dense(128, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(128, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(128, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(64, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(32, activation=activation_function),
    tf.keras.layers.Dense(5, activation='softmax')
])

# compile model
model.compile(
    loss=tf.keras.losses.categorical_crossentropy,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['categorical_accuracy']
)

# train model
history = model.fit(
    X_train_scaled,
    y_train_cat_array,
    epochs=250,
    validation_data=(X_test_scaled, y_test_cat_array),      # Ideally a validation split would be used here, but for our example the test data has been used for validation
    batch_size=32
)
# Out:
# Epoch 1/250
# 17/17 [==============================] - 1s 21ms/step - loss: 1.6040 - categorical_accuracy: 0.2652 - val_loss: 1.5957 - val_categorical_accuracy: 0.3182
# Epoch 2/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.6003 - categorical_accuracy: 0.2595 - val_loss: 1.5813 - val_categorical_accuracy: 0.3182
# Epoch 3/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.5855 - categorical_accuracy: 0.2727 - val_loss: 1.5682 - val_categorical_accuracy: 0.3182
# Epoch 4/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.5743 - categorical_accuracy: 0.2860 - val_loss: 1.5512 - val_categorical_accuracy: 0.3182
# Epoch 5/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.5637 - categorical_accuracy: 0.3106 - val_loss: 1.5330 - val_categorical_accuracy: 0.3182
# Epoch 6/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.5512 - categorical_accuracy: 0.3049 - val_loss: 1.5131 - val_categorical_accuracy: 0.3239
# Epoch 7/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.5320 - categorical_accuracy: 0.3049 - val_loss: 1.4924 - val_categorical_accuracy: 0.3693
# Epoch 8/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.5181 - categorical_accuracy: 0.3352 - val_loss: 1.4684 - val_categorical_accuracy: 0.5966
# Epoch 9/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.5001 - categorical_accuracy: 0.3333 - val_loss: 1.4383 - val_categorical_accuracy: 0.5966
# Epoch 10/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.4729 - categorical_accuracy: 0.3977 - val_loss: 1.3987 - val_categorical_accuracy: 0.6591
# Epoch 11/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.4465 - categorical_accuracy: 0.4053 - val_loss: 1.3522 - val_categorical_accuracy: 0.6364
# Epoch 12/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.4134 - categorical_accuracy: 0.4356 - val_loss: 1.3022 - val_categorical_accuracy: 0.6591
# Epoch 13/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.3603 - categorical_accuracy: 0.4640 - val_loss: 1.2331 - val_categorical_accuracy: 0.6761
# Epoch 14/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.3161 - categorical_accuracy: 0.4886 - val_loss: 1.1756 - val_categorical_accuracy: 0.6818
# Epoch 15/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.2588 - categorical_accuracy: 0.5208 - val_loss: 1.1104 - val_categorical_accuracy: 0.6818
# Epoch 16/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.1926 - categorical_accuracy: 0.5473 - val_loss: 1.0431 - val_categorical_accuracy: 0.6818
# Epoch 17/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.1246 - categorical_accuracy: 0.5663 - val_loss: 0.9719 - val_categorical_accuracy: 0.6818
# Epoch 18/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.0813 - categorical_accuracy: 0.5795 - val_loss: 0.8977 - val_categorical_accuracy: 0.6818
# Epoch 19/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.0407 - categorical_accuracy: 0.5947 - val_loss: 0.8375 - val_categorical_accuracy: 0.6818
# Epoch 20/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9579 - categorical_accuracy: 0.6439 - val_loss: 0.7745 - val_categorical_accuracy: 0.6875
# Epoch 21/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9067 - categorical_accuracy: 0.6534 - val_loss: 0.7174 - val_categorical_accuracy: 0.8125
# Epoch 22/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8607 - categorical_accuracy: 0.7027 - val_loss: 0.6637 - val_categorical_accuracy: 0.8239
# Epoch 23/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8517 - categorical_accuracy: 0.7008 - val_loss: 0.6205 - val_categorical_accuracy: 0.8352
# Epoch 24/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7750 - categorical_accuracy: 0.7367 - val_loss: 0.5805 - val_categorical_accuracy: 0.8523
# Epoch 25/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7582 - categorical_accuracy: 0.7595 - val_loss: 0.5371 - val_categorical_accuracy: 0.8580
# Epoch 26/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6996 - categorical_accuracy: 0.7727 - val_loss: 0.5063 - val_categorical_accuracy: 0.8693
# Epoch 27/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6834 - categorical_accuracy: 0.7955 - val_loss: 0.4820 - val_categorical_accuracy: 0.8636
# Epoch 28/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6799 - categorical_accuracy: 0.7746 - val_loss: 0.4575 - val_categorical_accuracy: 0.8750
# Epoch 29/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6336 - categorical_accuracy: 0.8030 - val_loss: 0.4309 - val_categorical_accuracy: 0.8977
# Epoch 30/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6453 - categorical_accuracy: 0.8144 - val_loss: 0.4245 - val_categorical_accuracy: 0.8807
# Epoch 31/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6292 - categorical_accuracy: 0.8087 - val_loss: 0.4080 - val_categorical_accuracy: 0.8807
# Epoch 32/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6245 - categorical_accuracy: 0.8087 - val_loss: 0.3956 - val_categorical_accuracy: 0.8920
# Epoch 33/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5850 - categorical_accuracy: 0.8447 - val_loss: 0.3720 - val_categorical_accuracy: 0.8977
# Epoch 34/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5867 - categorical_accuracy: 0.8258 - val_loss: 0.3715 - val_categorical_accuracy: 0.8977
# Epoch 35/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5354 - categorical_accuracy: 0.8352 - val_loss: 0.3544 - val_categorical_accuracy: 0.9148
# Epoch 36/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5265 - categorical_accuracy: 0.8333 - val_loss: 0.3429 - val_categorical_accuracy: 0.9091
# Epoch 37/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5248 - categorical_accuracy: 0.8504 - val_loss: 0.3268 - val_categorical_accuracy: 0.9261
# Epoch 38/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4886 - categorical_accuracy: 0.8750 - val_loss: 0.3114 - val_categorical_accuracy: 0.9318
# Epoch 39/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4980 - categorical_accuracy: 0.8598 - val_loss: 0.3061 - val_categorical_accuracy: 0.9261
# Epoch 40/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4802 - categorical_accuracy: 0.8750 - val_loss: 0.2975 - val_categorical_accuracy: 0.9318
# Epoch 41/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4482 - categorical_accuracy: 0.8864 - val_loss: 0.2900 - val_categorical_accuracy: 0.9318
# Epoch 42/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4417 - categorical_accuracy: 0.8826 - val_loss: 0.2811 - val_categorical_accuracy: 0.9375
# Epoch 43/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4401 - categorical_accuracy: 0.8845 - val_loss: 0.2735 - val_categorical_accuracy: 0.9375
# Epoch 44/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4175 - categorical_accuracy: 0.8826 - val_loss: 0.2650 - val_categorical_accuracy: 0.9375
# Epoch 45/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4381 - categorical_accuracy: 0.8902 - val_loss: 0.2619 - val_categorical_accuracy: 0.9375
# Epoch 46/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4235 - categorical_accuracy: 0.8826 - val_loss: 0.2573 - val_categorical_accuracy: 0.9375
# Epoch 47/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3915 - categorical_accuracy: 0.8864 - val_loss: 0.2436 - val_categorical_accuracy: 0.9375
# Epoch 48/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3631 - categorical_accuracy: 0.8939 - val_loss: 0.2327 - val_categorical_accuracy: 0.9375
# Epoch 49/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3974 - categorical_accuracy: 0.8864 - val_loss: 0.2314 - val_categorical_accuracy: 0.9375
# Epoch 50/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3575 - categorical_accuracy: 0.9072 - val_loss: 0.2299 - val_categorical_accuracy: 0.9375
# Epoch 51/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3277 - categorical_accuracy: 0.9186 - val_loss: 0.2196 - val_categorical_accuracy: 0.9375
# Epoch 52/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3398 - categorical_accuracy: 0.9072 - val_loss: 0.2137 - val_categorical_accuracy: 0.9375
# Epoch 53/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3554 - categorical_accuracy: 0.9091 - val_loss: 0.2144 - val_categorical_accuracy: 0.9375
# Epoch 54/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3258 - categorical_accuracy: 0.9148 - val_loss: 0.2096 - val_categorical_accuracy: 0.9375
# Epoch 55/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3337 - categorical_accuracy: 0.9205 - val_loss: 0.2034 - val_categorical_accuracy: 0.9432
# Epoch 56/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3218 - categorical_accuracy: 0.9186 - val_loss: 0.2013 - val_categorical_accuracy: 0.9375
# Epoch 57/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3180 - categorical_accuracy: 0.9110 - val_loss: 0.2018 - val_categorical_accuracy: 0.9375
# Epoch 58/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2914 - categorical_accuracy: 0.9375 - val_loss: 0.1985 - val_categorical_accuracy: 0.9375
# Epoch 59/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2887 - categorical_accuracy: 0.9318 - val_loss: 0.1945 - val_categorical_accuracy: 0.9375
# Epoch 60/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3012 - categorical_accuracy: 0.9242 - val_loss: 0.1939 - val_categorical_accuracy: 0.9432
# Epoch 61/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2994 - categorical_accuracy: 0.9242 - val_loss: 0.1920 - val_categorical_accuracy: 0.9375
# Epoch 62/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2809 - categorical_accuracy: 0.9223 - val_loss: 0.1880 - val_categorical_accuracy: 0.9489
# Epoch 63/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2721 - categorical_accuracy: 0.9242 - val_loss: 0.1846 - val_categorical_accuracy: 0.9432
# Epoch 64/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2874 - categorical_accuracy: 0.9318 - val_loss: 0.1856 - val_categorical_accuracy: 0.9489
# Epoch 65/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3008 - categorical_accuracy: 0.9129 - val_loss: 0.1825 - val_categorical_accuracy: 0.9489
# Epoch 66/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2731 - categorical_accuracy: 0.9337 - val_loss: 0.1801 - val_categorical_accuracy: 0.9489
# Epoch 67/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2413 - categorical_accuracy: 0.9337 - val_loss: 0.1799 - val_categorical_accuracy: 0.9489
# Epoch 68/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2623 - categorical_accuracy: 0.9280 - val_loss: 0.1772 - val_categorical_accuracy: 0.9489
# Epoch 69/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2720 - categorical_accuracy: 0.9318 - val_loss: 0.1751 - val_categorical_accuracy: 0.9489
# Epoch 70/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2424 - categorical_accuracy: 0.9413 - val_loss: 0.1767 - val_categorical_accuracy: 0.9489
# Epoch 71/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2506 - categorical_accuracy: 0.9375 - val_loss: 0.1741 - val_categorical_accuracy: 0.9489
# Epoch 72/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2514 - categorical_accuracy: 0.9394 - val_loss: 0.1723 - val_categorical_accuracy: 0.9489
# Epoch 73/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2599 - categorical_accuracy: 0.9318 - val_loss: 0.1703 - val_categorical_accuracy: 0.9489
# Epoch 74/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2378 - categorical_accuracy: 0.9413 - val_loss: 0.1686 - val_categorical_accuracy: 0.9489
# Epoch 75/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2355 - categorical_accuracy: 0.9318 - val_loss: 0.1732 - val_categorical_accuracy: 0.9489
# Epoch 76/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2409 - categorical_accuracy: 0.9489 - val_loss: 0.1719 - val_categorical_accuracy: 0.9489
# Epoch 77/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2268 - categorical_accuracy: 0.9432 - val_loss: 0.1704 - val_categorical_accuracy: 0.9489
# Epoch 78/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2410 - categorical_accuracy: 0.9394 - val_loss: 0.1684 - val_categorical_accuracy: 0.9489
# Epoch 79/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2308 - categorical_accuracy: 0.9375 - val_loss: 0.1658 - val_categorical_accuracy: 0.9489
# Epoch 80/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2015 - categorical_accuracy: 0.9489 - val_loss: 0.1670 - val_categorical_accuracy: 0.9489
# Epoch 81/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2143 - categorical_accuracy: 0.9451 - val_loss: 0.1681 - val_categorical_accuracy: 0.9489
# Epoch 82/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2322 - categorical_accuracy: 0.9394 - val_loss: 0.1683 - val_categorical_accuracy: 0.9489
# Epoch 83/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2230 - categorical_accuracy: 0.9413 - val_loss: 0.1656 - val_categorical_accuracy: 0.9489
# Epoch 84/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2251 - categorical_accuracy: 0.9375 - val_loss: 0.1641 - val_categorical_accuracy: 0.9489
# Epoch 85/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2203 - categorical_accuracy: 0.9375 - val_loss: 0.1657 - val_categorical_accuracy: 0.9489
# Epoch 86/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2122 - categorical_accuracy: 0.9413 - val_loss: 0.1663 - val_categorical_accuracy: 0.9545
# Epoch 87/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2118 - categorical_accuracy: 0.9413 - val_loss: 0.1670 - val_categorical_accuracy: 0.9432
# Epoch 88/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1972 - categorical_accuracy: 0.9432 - val_loss: 0.1670 - val_categorical_accuracy: 0.9489
# Epoch 89/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2181 - categorical_accuracy: 0.9394 - val_loss: 0.1619 - val_categorical_accuracy: 0.9545
# Epoch 90/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2013 - categorical_accuracy: 0.9432 - val_loss: 0.1607 - val_categorical_accuracy: 0.9489
# Epoch 91/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1998 - categorical_accuracy: 0.9451 - val_loss: 0.1644 - val_categorical_accuracy: 0.9489
# Epoch 92/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2144 - categorical_accuracy: 0.9508 - val_loss: 0.1599 - val_categorical_accuracy: 0.9489
# Epoch 93/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2024 - categorical_accuracy: 0.9470 - val_loss: 0.1606 - val_categorical_accuracy: 0.9545
# Epoch 94/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2055 - categorical_accuracy: 0.9413 - val_loss: 0.1609 - val_categorical_accuracy: 0.9489
# Epoch 95/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2394 - categorical_accuracy: 0.9413 - val_loss: 0.1633 - val_categorical_accuracy: 0.9489
# Epoch 96/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1914 - categorical_accuracy: 0.9527 - val_loss: 0.1593 - val_categorical_accuracy: 0.9489
# Epoch 97/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1775 - categorical_accuracy: 0.9489 - val_loss: 0.1584 - val_categorical_accuracy: 0.9489
# Epoch 98/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1924 - categorical_accuracy: 0.9432 - val_loss: 0.1596 - val_categorical_accuracy: 0.9489
# Epoch 99/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1987 - categorical_accuracy: 0.9489 - val_loss: 0.1570 - val_categorical_accuracy: 0.9489
# Epoch 100/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1722 - categorical_accuracy: 0.9508 - val_loss: 0.1558 - val_categorical_accuracy: 0.9489
# Epoch 101/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1784 - categorical_accuracy: 0.9527 - val_loss: 0.1540 - val_categorical_accuracy: 0.9545
# Epoch 102/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1897 - categorical_accuracy: 0.9508 - val_loss: 0.1535 - val_categorical_accuracy: 0.9545
# Epoch 103/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1941 - categorical_accuracy: 0.9508 - val_loss: 0.1529 - val_categorical_accuracy: 0.9545
# Epoch 104/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1833 - categorical_accuracy: 0.9489 - val_loss: 0.1521 - val_categorical_accuracy: 0.9489
# Epoch 105/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1887 - categorical_accuracy: 0.9451 - val_loss: 0.1568 - val_categorical_accuracy: 0.9489
# Epoch 106/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2135 - categorical_accuracy: 0.9432 - val_loss: 0.1532 - val_categorical_accuracy: 0.9545
# Epoch 107/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1985 - categorical_accuracy: 0.9489 - val_loss: 0.1516 - val_categorical_accuracy: 0.9545
# Epoch 108/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1809 - categorical_accuracy: 0.9527 - val_loss: 0.1551 - val_categorical_accuracy: 0.9489
# Epoch 109/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1863 - categorical_accuracy: 0.9489 - val_loss: 0.1506 - val_categorical_accuracy: 0.9489
# Epoch 110/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1730 - categorical_accuracy: 0.9451 - val_loss: 0.1496 - val_categorical_accuracy: 0.9545
# Epoch 111/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1757 - categorical_accuracy: 0.9489 - val_loss: 0.1504 - val_categorical_accuracy: 0.9545
# Epoch 112/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1923 - categorical_accuracy: 0.9375 - val_loss: 0.1495 - val_categorical_accuracy: 0.9545
# Epoch 113/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2091 - categorical_accuracy: 0.9375 - val_loss: 0.1489 - val_categorical_accuracy: 0.9545
# Epoch 114/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2002 - categorical_accuracy: 0.9394 - val_loss: 0.1496 - val_categorical_accuracy: 0.9489
# Epoch 115/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1691 - categorical_accuracy: 0.9489 - val_loss: 0.1479 - val_categorical_accuracy: 0.9545
# Epoch 116/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1874 - categorical_accuracy: 0.9451 - val_loss: 0.1493 - val_categorical_accuracy: 0.9545
# Epoch 117/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1834 - categorical_accuracy: 0.9432 - val_loss: 0.1502 - val_categorical_accuracy: 0.9545
# Epoch 118/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1737 - categorical_accuracy: 0.9470 - val_loss: 0.1480 - val_categorical_accuracy: 0.9545
# Epoch 119/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1693 - categorical_accuracy: 0.9508 - val_loss: 0.1469 - val_categorical_accuracy: 0.9545
# Epoch 120/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1866 - categorical_accuracy: 0.9508 - val_loss: 0.1462 - val_categorical_accuracy: 0.9545
# Epoch 121/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1626 - categorical_accuracy: 0.9470 - val_loss: 0.1483 - val_categorical_accuracy: 0.9489
# Epoch 122/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1775 - categorical_accuracy: 0.9489 - val_loss: 0.1498 - val_categorical_accuracy: 0.9489
# Epoch 123/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1639 - categorical_accuracy: 0.9545 - val_loss: 0.1462 - val_categorical_accuracy: 0.9545
# Epoch 124/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1773 - categorical_accuracy: 0.9489 - val_loss: 0.1461 - val_categorical_accuracy: 0.9545
# Epoch 125/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1566 - categorical_accuracy: 0.9508 - val_loss: 0.1475 - val_categorical_accuracy: 0.9545
# Epoch 126/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1745 - categorical_accuracy: 0.9508 - val_loss: 0.1490 - val_categorical_accuracy: 0.9489
# Epoch 127/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1668 - categorical_accuracy: 0.9432 - val_loss: 0.1456 - val_categorical_accuracy: 0.9545
# Epoch 128/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1885 - categorical_accuracy: 0.9451 - val_loss: 0.1469 - val_categorical_accuracy: 0.9545
# Epoch 129/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1712 - categorical_accuracy: 0.9527 - val_loss: 0.1442 - val_categorical_accuracy: 0.9545
# Epoch 130/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1662 - categorical_accuracy: 0.9564 - val_loss: 0.1434 - val_categorical_accuracy: 0.9545
# Epoch 131/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1516 - categorical_accuracy: 0.9545 - val_loss: 0.1430 - val_categorical_accuracy: 0.9545
# Epoch 132/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1697 - categorical_accuracy: 0.9508 - val_loss: 0.1446 - val_categorical_accuracy: 0.9545
# Epoch 133/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1428 - categorical_accuracy: 0.9583 - val_loss: 0.1467 - val_categorical_accuracy: 0.9489
# Epoch 134/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1614 - categorical_accuracy: 0.9545 - val_loss: 0.1454 - val_categorical_accuracy: 0.9545
# Epoch 135/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1597 - categorical_accuracy: 0.9545 - val_loss: 0.1431 - val_categorical_accuracy: 0.9545
# Epoch 136/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1753 - categorical_accuracy: 0.9413 - val_loss: 0.1413 - val_categorical_accuracy: 0.9545
# Epoch 137/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1542 - categorical_accuracy: 0.9564 - val_loss: 0.1426 - val_categorical_accuracy: 0.9545
# Epoch 138/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1472 - categorical_accuracy: 0.9564 - val_loss: 0.1426 - val_categorical_accuracy: 0.9545
# Epoch 139/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1691 - categorical_accuracy: 0.9508 - val_loss: 0.1422 - val_categorical_accuracy: 0.9545
# Epoch 140/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1556 - categorical_accuracy: 0.9545 - val_loss: 0.1440 - val_categorical_accuracy: 0.9545
# Epoch 141/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1514 - categorical_accuracy: 0.9564 - val_loss: 0.1497 - val_categorical_accuracy: 0.9489
# Epoch 142/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1781 - categorical_accuracy: 0.9451 - val_loss: 0.1456 - val_categorical_accuracy: 0.9545
# Epoch 143/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1529 - categorical_accuracy: 0.9470 - val_loss: 0.1416 - val_categorical_accuracy: 0.9545
# Epoch 144/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1517 - categorical_accuracy: 0.9508 - val_loss: 0.1426 - val_categorical_accuracy: 0.9489
# Epoch 145/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1563 - categorical_accuracy: 0.9527 - val_loss: 0.1453 - val_categorical_accuracy: 0.9489
# Epoch 146/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1621 - categorical_accuracy: 0.9508 - val_loss: 0.1433 - val_categorical_accuracy: 0.9545
# Epoch 147/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1570 - categorical_accuracy: 0.9470 - val_loss: 0.1411 - val_categorical_accuracy: 0.9545
# Epoch 148/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1567 - categorical_accuracy: 0.9527 - val_loss: 0.1403 - val_categorical_accuracy: 0.9545
# Epoch 149/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1531 - categorical_accuracy: 0.9545 - val_loss: 0.1394 - val_categorical_accuracy: 0.9545
# Epoch 150/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1652 - categorical_accuracy: 0.9527 - val_loss: 0.1397 - val_categorical_accuracy: 0.9545
# Epoch 151/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1773 - categorical_accuracy: 0.9451 - val_loss: 0.1403 - val_categorical_accuracy: 0.9545
# Epoch 152/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1540 - categorical_accuracy: 0.9527 - val_loss: 0.1395 - val_categorical_accuracy: 0.9545
# Epoch 153/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1480 - categorical_accuracy: 0.9564 - val_loss: 0.1390 - val_categorical_accuracy: 0.9545
# Epoch 154/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1492 - categorical_accuracy: 0.9564 - val_loss: 0.1389 - val_categorical_accuracy: 0.9545
# Epoch 155/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1512 - categorical_accuracy: 0.9564 - val_loss: 0.1385 - val_categorical_accuracy: 0.9545
# Epoch 156/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1508 - categorical_accuracy: 0.9545 - val_loss: 0.1388 - val_categorical_accuracy: 0.9545
# Epoch 157/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1529 - categorical_accuracy: 0.9508 - val_loss: 0.1422 - val_categorical_accuracy: 0.9545
# Epoch 158/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1550 - categorical_accuracy: 0.9545 - val_loss: 0.1402 - val_categorical_accuracy: 0.9545
# Epoch 159/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1545 - categorical_accuracy: 0.9545 - val_loss: 0.1394 - val_categorical_accuracy: 0.9545
# Epoch 160/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1507 - categorical_accuracy: 0.9545 - val_loss: 0.1415 - val_categorical_accuracy: 0.9545
# Epoch 161/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1400 - categorical_accuracy: 0.9545 - val_loss: 0.1466 - val_categorical_accuracy: 0.9489
# Epoch 162/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1513 - categorical_accuracy: 0.9564 - val_loss: 0.1436 - val_categorical_accuracy: 0.9545
# Epoch 163/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1731 - categorical_accuracy: 0.9470 - val_loss: 0.1409 - val_categorical_accuracy: 0.9545
# Epoch 164/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1445 - categorical_accuracy: 0.9564 - val_loss: 0.1480 - val_categorical_accuracy: 0.9489
# Epoch 165/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1545 - categorical_accuracy: 0.9545 - val_loss: 0.1483 - val_categorical_accuracy: 0.9489
# Epoch 166/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1468 - categorical_accuracy: 0.9545 - val_loss: 0.1402 - val_categorical_accuracy: 0.9545
# Epoch 167/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1420 - categorical_accuracy: 0.9545 - val_loss: 0.1395 - val_categorical_accuracy: 0.9545
# Epoch 168/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1550 - categorical_accuracy: 0.9508 - val_loss: 0.1379 - val_categorical_accuracy: 0.9545
# Epoch 169/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1543 - categorical_accuracy: 0.9545 - val_loss: 0.1369 - val_categorical_accuracy: 0.9545
# Epoch 170/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1416 - categorical_accuracy: 0.9545 - val_loss: 0.1378 - val_categorical_accuracy: 0.9545
# Epoch 171/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1554 - categorical_accuracy: 0.9527 - val_loss: 0.1387 - val_categorical_accuracy: 0.9545
# Epoch 172/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1550 - categorical_accuracy: 0.9470 - val_loss: 0.1374 - val_categorical_accuracy: 0.9545
# Epoch 173/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1439 - categorical_accuracy: 0.9508 - val_loss: 0.1354 - val_categorical_accuracy: 0.9545
# Epoch 174/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1458 - categorical_accuracy: 0.9583 - val_loss: 0.1358 - val_categorical_accuracy: 0.9545
# Epoch 175/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1506 - categorical_accuracy: 0.9564 - val_loss: 0.1366 - val_categorical_accuracy: 0.9545
# Epoch 176/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1509 - categorical_accuracy: 0.9508 - val_loss: 0.1347 - val_categorical_accuracy: 0.9545
# Epoch 177/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1386 - categorical_accuracy: 0.9527 - val_loss: 0.1367 - val_categorical_accuracy: 0.9545
# Epoch 178/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1435 - categorical_accuracy: 0.9527 - val_loss: 0.1410 - val_categorical_accuracy: 0.9489
# Epoch 179/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1411 - categorical_accuracy: 0.9564 - val_loss: 0.1372 - val_categorical_accuracy: 0.9545
# Epoch 180/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1426 - categorical_accuracy: 0.9545 - val_loss: 0.1358 - val_categorical_accuracy: 0.9545
# Epoch 181/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1416 - categorical_accuracy: 0.9564 - val_loss: 0.1379 - val_categorical_accuracy: 0.9545
# Epoch 182/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1370 - categorical_accuracy: 0.9545 - val_loss: 0.1378 - val_categorical_accuracy: 0.9489
# Epoch 183/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1455 - categorical_accuracy: 0.9508 - val_loss: 0.1364 - val_categorical_accuracy: 0.9602
# Epoch 184/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1273 - categorical_accuracy: 0.9602 - val_loss: 0.1385 - val_categorical_accuracy: 0.9545
# Epoch 185/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1569 - categorical_accuracy: 0.9545 - val_loss: 0.1332 - val_categorical_accuracy: 0.9545
# Epoch 186/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1382 - categorical_accuracy: 0.9621 - val_loss: 0.1348 - val_categorical_accuracy: 0.9545
# Epoch 187/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1479 - categorical_accuracy: 0.9508 - val_loss: 0.1346 - val_categorical_accuracy: 0.9545
# Epoch 188/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1564 - categorical_accuracy: 0.9527 - val_loss: 0.1338 - val_categorical_accuracy: 0.9545
# Epoch 189/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1384 - categorical_accuracy: 0.9508 - val_loss: 0.1338 - val_categorical_accuracy: 0.9545
# Epoch 190/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1332 - categorical_accuracy: 0.9602 - val_loss: 0.1333 - val_categorical_accuracy: 0.9545
# Epoch 191/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1353 - categorical_accuracy: 0.9545 - val_loss: 0.1363 - val_categorical_accuracy: 0.9545
# Epoch 192/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1431 - categorical_accuracy: 0.9564 - val_loss: 0.1341 - val_categorical_accuracy: 0.9545
# Epoch 193/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1543 - categorical_accuracy: 0.9451 - val_loss: 0.1346 - val_categorical_accuracy: 0.9602
# Epoch 194/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1347 - categorical_accuracy: 0.9583 - val_loss: 0.1367 - val_categorical_accuracy: 0.9545
# Epoch 195/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1289 - categorical_accuracy: 0.9527 - val_loss: 0.1376 - val_categorical_accuracy: 0.9545
# Epoch 196/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1311 - categorical_accuracy: 0.9508 - val_loss: 0.1391 - val_categorical_accuracy: 0.9545
# Epoch 197/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1375 - categorical_accuracy: 0.9602 - val_loss: 0.1372 - val_categorical_accuracy: 0.9545
# Epoch 198/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1344 - categorical_accuracy: 0.9564 - val_loss: 0.1385 - val_categorical_accuracy: 0.9545
# Epoch 199/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1184 - categorical_accuracy: 0.9640 - val_loss: 0.1367 - val_categorical_accuracy: 0.9545
# Epoch 200/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1423 - categorical_accuracy: 0.9583 - val_loss: 0.1367 - val_categorical_accuracy: 0.9545
# Epoch 201/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1483 - categorical_accuracy: 0.9527 - val_loss: 0.1367 - val_categorical_accuracy: 0.9545
# Epoch 202/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1372 - categorical_accuracy: 0.9602 - val_loss: 0.1336 - val_categorical_accuracy: 0.9545
# Epoch 203/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1482 - categorical_accuracy: 0.9545 - val_loss: 0.1328 - val_categorical_accuracy: 0.9545
# Epoch 204/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1450 - categorical_accuracy: 0.9545 - val_loss: 0.1340 - val_categorical_accuracy: 0.9545
# Epoch 205/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1394 - categorical_accuracy: 0.9564 - val_loss: 0.1342 - val_categorical_accuracy: 0.9545
# Epoch 206/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1420 - categorical_accuracy: 0.9508 - val_loss: 0.1349 - val_categorical_accuracy: 0.9545
# Epoch 207/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1333 - categorical_accuracy: 0.9621 - val_loss: 0.1376 - val_categorical_accuracy: 0.9545
# Epoch 208/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1367 - categorical_accuracy: 0.9564 - val_loss: 0.1326 - val_categorical_accuracy: 0.9545
# Epoch 209/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1335 - categorical_accuracy: 0.9527 - val_loss: 0.1327 - val_categorical_accuracy: 0.9545
# Epoch 210/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1296 - categorical_accuracy: 0.9564 - val_loss: 0.1357 - val_categorical_accuracy: 0.9545
# Epoch 211/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1403 - categorical_accuracy: 0.9508 - val_loss: 0.1354 - val_categorical_accuracy: 0.9545
# Epoch 212/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1317 - categorical_accuracy: 0.9621 - val_loss: 0.1325 - val_categorical_accuracy: 0.9545
# Epoch 213/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1353 - categorical_accuracy: 0.9545 - val_loss: 0.1314 - val_categorical_accuracy: 0.9545
# Epoch 214/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1216 - categorical_accuracy: 0.9564 - val_loss: 0.1325 - val_categorical_accuracy: 0.9545
# Epoch 215/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1383 - categorical_accuracy: 0.9564 - val_loss: 0.1340 - val_categorical_accuracy: 0.9545
# Epoch 216/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1212 - categorical_accuracy: 0.9602 - val_loss: 0.1355 - val_categorical_accuracy: 0.9545
# Epoch 217/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1300 - categorical_accuracy: 0.9583 - val_loss: 0.1353 - val_categorical_accuracy: 0.9545
# Epoch 218/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1401 - categorical_accuracy: 0.9583 - val_loss: 0.1308 - val_categorical_accuracy: 0.9545
# Epoch 219/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1227 - categorical_accuracy: 0.9527 - val_loss: 0.1329 - val_categorical_accuracy: 0.9602
# Epoch 220/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1182 - categorical_accuracy: 0.9659 - val_loss: 0.1335 - val_categorical_accuracy: 0.9545
# Epoch 221/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1153 - categorical_accuracy: 0.9564 - val_loss: 0.1336 - val_categorical_accuracy: 0.9545
# Epoch 222/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1296 - categorical_accuracy: 0.9602 - val_loss: 0.1368 - val_categorical_accuracy: 0.9545
# Epoch 223/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1219 - categorical_accuracy: 0.9564 - val_loss: 0.1359 - val_categorical_accuracy: 0.9545
# Epoch 224/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1408 - categorical_accuracy: 0.9527 - val_loss: 0.1377 - val_categorical_accuracy: 0.9489
# Epoch 225/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1283 - categorical_accuracy: 0.9602 - val_loss: 0.1383 - val_categorical_accuracy: 0.9545
# Epoch 226/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1142 - categorical_accuracy: 0.9602 - val_loss: 0.1345 - val_categorical_accuracy: 0.9545
# Epoch 227/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1423 - categorical_accuracy: 0.9545 - val_loss: 0.1329 - val_categorical_accuracy: 0.9545
# Epoch 228/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1248 - categorical_accuracy: 0.9508 - val_loss: 0.1346 - val_categorical_accuracy: 0.9545
# Epoch 229/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1174 - categorical_accuracy: 0.9583 - val_loss: 0.1304 - val_categorical_accuracy: 0.9545
# Epoch 230/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1290 - categorical_accuracy: 0.9564 - val_loss: 0.1313 - val_categorical_accuracy: 0.9545
# Epoch 231/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1299 - categorical_accuracy: 0.9602 - val_loss: 0.1329 - val_categorical_accuracy: 0.9545
# Epoch 232/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1295 - categorical_accuracy: 0.9640 - val_loss: 0.1315 - val_categorical_accuracy: 0.9545
# Epoch 233/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1218 - categorical_accuracy: 0.9545 - val_loss: 0.1339 - val_categorical_accuracy: 0.9545
# Epoch 234/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1333 - categorical_accuracy: 0.9470 - val_loss: 0.1366 - val_categorical_accuracy: 0.9489
# Epoch 235/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1246 - categorical_accuracy: 0.9564 - val_loss: 0.1308 - val_categorical_accuracy: 0.9545
# Epoch 236/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1203 - categorical_accuracy: 0.9583 - val_loss: 0.1304 - val_categorical_accuracy: 0.9545
# Epoch 237/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1265 - categorical_accuracy: 0.9583 - val_loss: 0.1360 - val_categorical_accuracy: 0.9545
# Epoch 238/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1238 - categorical_accuracy: 0.9564 - val_loss: 0.1343 - val_categorical_accuracy: 0.9545
# Epoch 239/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1203 - categorical_accuracy: 0.9640 - val_loss: 0.1308 - val_categorical_accuracy: 0.9545
# Epoch 240/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1160 - categorical_accuracy: 0.9583 - val_loss: 0.1326 - val_categorical_accuracy: 0.9545
# Epoch 241/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1115 - categorical_accuracy: 0.9640 - val_loss: 0.1331 - val_categorical_accuracy: 0.9545
# Epoch 242/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1268 - categorical_accuracy: 0.9564 - val_loss: 0.1319 - val_categorical_accuracy: 0.9545
# Epoch 243/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1312 - categorical_accuracy: 0.9564 - val_loss: 0.1319 - val_categorical_accuracy: 0.9545
# Epoch 244/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1332 - categorical_accuracy: 0.9564 - val_loss: 0.1325 - val_categorical_accuracy: 0.9489
# Epoch 245/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1113 - categorical_accuracy: 0.9621 - val_loss: 0.1331 - val_categorical_accuracy: 0.9545
# Epoch 246/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1326 - categorical_accuracy: 0.9527 - val_loss: 0.1352 - val_categorical_accuracy: 0.9489
# Epoch 247/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1253 - categorical_accuracy: 0.9583 - val_loss: 0.1340 - val_categorical_accuracy: 0.9545
# Epoch 248/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1217 - categorical_accuracy: 0.9583 - val_loss: 0.1324 - val_categorical_accuracy: 0.9545
# Epoch 249/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1351 - categorical_accuracy: 0.9508 - val_loss: 0.1362 - val_categorical_accuracy: 0.9489
# Epoch 250/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1040 - categorical_accuracy: 0.9583 - val_loss: 0.1355 - val_categorical_accuracy: 0.9489

# %% [markdown]
# ## Performance metrics

# %%
print("*****    PERFORMANCE METRICS    ***** ")
print(" MAX VAL ACCURACY: " + str(max(history.history['val_categorical_accuracy'])))
print("            EPOCH: " + str(history.history['val_categorical_accuracy'].index(max(history.history['val_categorical_accuracy'])) +1))
print("     MIN VAL LOSS: " + str(min(history.history['val_loss'])))
print("            EPOCH: " + str(history.history['val_loss'].index(min(history.history['val_loss'])) +1))
# Out:
# *****    PERFORMANCE METRICS    *****
#  MAX VAL ACCURACY: 0.9602272510528564
#             EPOCH: 183
#      MIN VAL LOSS: 0.13037365674972534
#             EPOCH: 229

# %% [markdown]
# ## Visualise accuracy and loss curves

# %%
# Plot the validation and training curves separately
def plot_loss_curves(history_object):
    """
    Returns separate loss curves for training and validation datasets.
    """

    loss = history_object.history['loss']
    val_loss = history_object.history['val_loss']
    accuracy = history_object.history['categorical_accuracy']
    val_accuracy = history_object.history['val_categorical_accuracy']
    epochs = range(len(history_object.history['loss']))    # how many epochs did we run for

    # plot loss
    plt.figure()
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('loss')
    plt.xlabel('epochs')
    plt.legend()

    # plot accuracy
    plt.figure()
    plt.plot(epochs, accuracy, label='training_cat_accuracy')
    plt.plot(epochs, val_accuracy, label='val_cat_accuracy')
    plt.title('accuracy')
    plt.xlabel('epochs')
    plt.legend()

# %%
plot_loss_curves(history)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Plot confusion matrix

# %%
# make predictions with NN model
y_predicted = model.predict(X_test_scaled)
y_predicted = np.argmax(y_predicted, axis=1)
# Out:
# 6/6 [==============================] - 0s 1ms/step

# %%
matrix = confusion_matrix(y_test, y_predicted)
plot_nn_cm(conf_mat=matrix, class_names=['Standing', 'Walking', 'Jogging', 'Side-Step', 'Running'], show_normed=True)
# Store categorical accuracy for comparison to other models
nn_cat_accuracy = list(matrix.diagonal()/matrix.sum(axis=1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Conclusion

# %%
# chart up categorical accuracy score for each model in histogram
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
fig.suptitle("Categorical Accuracy - Model Comparison \n(Test Dataset)")
# plot categorical accuracy for each classifier
X_axis1 = np.arange(len(knn_cat_accuracy))
#X_axis1 = ["Standing", "Walking", "Jogging", "Side-Step", "Running"]
bar_width = 0.2
ax[0].bar(X_axis1 -0.0, knn_cat_accuracy, bar_width, label="KNN Classifier")
ax[0].bar(X_axis1 +0.2, rf_cat_accuracy, bar_width, label="Random Forest")
ax[0].bar(X_axis1 +0.4, sgd_cat_accuracy, bar_width, label="SGD classifier")
ax[0].bar(X_axis1 +0.6, nn_cat_accuracy, bar_width, label="Neural Network")

ax[0].set_title("Categorical Accuracy")
ax[0].set_ylabel("Categorical Accuracy Score")
ax[0].set_ylim([0.8, 1.0])
# TODO: SET X LABELS FOR EACH CLASS
ax[0].set_xticklabels(["", "Standing", "Walking", "Jogging", "Side-Step", "Running"])
ax[0].legend()

# plot average categorical accuracy for each classifier
X_axis2 = ['KNN', 'RF', 'SGD', 'NN']
avg_cat_accuracy = [np.mean(knn_cat_accuracy), np.mean(rf_cat_accuracy), np.mean(sgd_cat_accuracy), np.mean(nn_cat_accuracy)]
ax[1].bar(X_axis2, avg_cat_accuracy)
ax[1].set_ylim(0.9, 1.0)
ax[1].set_title("Average Categorical Accuracy")
ax[1].set_ylabel("Categorical Accuracy Score")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# C:\Users\wills\AppData\Local\Temp\ipykernel_11860\61186719.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(["", "Standing", "Walking", "Jogging", "Side-Step", "Running"])
# Text(0, 0.5, 'Categorical Accuracy Score')

# %%
# discuss strong and weak points for each model
#   - KNN can suffer with unbalanced classes, sensitive to outliers
#   - RF pretty good straight out of the box, top performer on test set, and is generally fairly robust, not prone to over fitting, but may struggle with extreme outliers
#   - SGD being a linear model can have difficulty separating on some features, but generally has done an ok job for this experiment
#   - NN prone to over fitting in general, this is shown in the accuracy and loss curves in this experiment where the loss curves converge and the model continues to improve fitting to the test set (i allowed this to train for more epochs to demonstrate this)
#     but accuracy on test dataset was quite good

# good results on running class, mixed results on other classes

# discuss options to improve performance
#   - larger dataset
#   - further feature engineering
#   - more rigorous analysis of activity label assignment against video timetrack


# categorical accuracy probably the best metric for comparison, as false true/positive classification are less important in this study compared to that of the study such as the poisonous vs edible mushrooms, consequences are far less significant
