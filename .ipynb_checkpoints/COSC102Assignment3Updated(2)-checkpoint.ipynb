# %% [markdown]
# #                                  COSC102 Group Assignment 3
# # Machine Learning Portfolio
#
# # Group Members - Will Duckworth, Jim Purvis, David Anderson
#
# # KNN Classifier, RandomForest Classifier, SGD Classifier, Neural Network

# %% [markdown]
# # Import necessary libraries

# %%
# If tensorflow and mlxtend are not already installed, uncomment and run this cell
# !pip install tensorflow
# !pip install mlxtend
# Out:
# Requirement already satisfied: tensorflow in c:\users\wills\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: setuptools in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: numpy>=1.20 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: packaging in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\wills\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\wills\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\wills\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wills\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wills\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\wills\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\wills\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wills\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\wills\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wills\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: mlxtend in c:\users\wills\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (61.2.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\wills\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wills\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wills\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\wills\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wills\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)

# %%
import csv
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import math
import statistics
from sklearn import preprocessing, metrics
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn import neighbors
from sklearn.metrics import plot_confusion_matrix as plot_cm
from mlxtend.plotting import plot_confusion_matrix as plot_nn_cm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.utils.np_utils import to_categorical
import tensorflow as tf

# %% [markdown]
# # *** Data Preparation ***

# %% [markdown]
# ## Set the file paths for the 2 data sets to be read
# ## Convert the data to a Pandas DataFrame

# %%
imu_data_path = os.path.abspath("a3_imu_data.csv")

annotations_path = os.path.abspath("a3_activity_annotations.csv")

imu_data = pd.read_csv(imu_data_path, delimiter=",")

imu_data_frame = pd.DataFrame(data=imu_data)

annotations_data = pd.read_csv(annotations_path, delimiter=",")

annotations_data_frame = pd.DataFrame(data=annotations_data)

# %% [markdown]
# ## Create empty lists to store the separated data for each of the activity set data points

# %%
time_track = []
ax_set = []
ay_set = []
az_set = []

gx_set = []
gy_set = []
gz_set = []

activity_set = []

# %% [markdown]
# ## Create function to map the activity type and return an integer value for that activity

# %%
def map_activity(activity_string):
    if activity_string == 'Standing':
        return 0
    elif activity_string == 'Walking':
        return 1
    elif activity_string == 'Jogging':
        return 2
    elif activity_string == 'Side-Step':
        return 3
    elif activity_string == 'Running':
        return 4

# %% [markdown]
# ## Read in the data as a CSV, and append the lists depending on the label

# %%
with open(imu_data_path, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        time_track.append(float(row[0]))
        ax_set.append(float(row[1]))
        ay_set.append(float(row[2]))
        az_set.append(float(row[3]))
        gx_set.append(float(row[4]))
        gy_set.append(float(row[5]))
        gz_set.append(float(row[6]))

# %% [markdown]
# ## Create a color list to visualise the data from the plot

# %%
fig, axs = plt.subplots(2,1,figsize=(20,10))
fig.suptitle("Raw Data")
axs[0].plot(ax_set, color='r')
axs[0].plot(ay_set, color='g')
axs[0].plot(az_set, color='b')
axs[0].set_title("Accelerometer")
axs[0].set_xlabel("Sampling Increments")
axs[0].set_ylabel("Value")

axs[1].plot(gx_set, color='r')
axs[1].plot(gy_set, color='g')
axs[1].plot(gz_set, color='b')
axs[1].set_title("Gyroscope")
axs[1].set_xlabel("Sampling Increments")
axs[1].set_ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# ## Cut the data to the starting point of the activity, removing prior noise and sync the data to the video

# %%
start_idx = 825

fig, axs = plt.subplots(2,1,figsize=(20,10))
fig.suptitle("Raw Data After Clipping Start Point")
axs[0].plot(ax_set[start_idx:370000], color='r')
axs[0].plot(ay_set[start_idx:370000], color='g')
axs[0].plot(az_set[start_idx:370000], color='b')
axs[0].set_title("Accelerometer")
axs[0].set_xlabel("Sampling Increments")
axs[0].set_ylabel("Value")

axs[1].plot(gx_set[start_idx:370000], color='r')
axs[1].plot(gy_set[start_idx:370000], color='g')
axs[1].plot(gz_set[start_idx:370000], color='b')
axs[1].set_title("Gyroscope")
axs[1].set_xlabel("Sampling Increments")
axs[1].set_ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# ## Find the end point of the video and cut the unnecessary end noise

# %%
#Now we need to find the end point
start_ts = time_track[start_idx]
print(start_ts)

# The video has been cut to 443 seconds in length - need to find 
# Start_ts + 443 seconds. This should land us at the end point
# We can sanity check this by inspecting the plot

end_idx = time_track.index(start_ts+711)

# Sanity Check
fig, axs = plt.subplots(2,1,figsize=(20,10))
fig.suptitle("Raw Data After Clipping")
axs[0].plot(ax_set[start_idx:end_idx], color='r')
axs[0].plot(ay_set[start_idx:end_idx], color='g')
axs[0].plot(az_set[start_idx:end_idx], color='b')
axs[0].set_title("Accelerometer")
axs[0].set_xlabel("Sampling Increments")
axs[0].set_ylabel("Value")

axs[1].plot(gx_set[start_idx:end_idx], color='r')
axs[1].plot(gy_set[start_idx:end_idx], color='g')
axs[1].plot(gz_set[start_idx:end_idx], color='b')
axs[1].set_title("Gyroscope")
axs[1].set_xlabel("Sampling Increments")
axs[1].set_ylabel("Value")
# Out:
# 1598240221.0
# Text(0, 0.5, 'Value')

# %% [markdown]
# ## Read in the annotations file data as CSV, iterate through the data and separate to get the time stamp

# %%
with open(annotations_path, newline='') as f:
    reader = csv.reader(f)
    next(reader, None)  # skip the headers
    for row in reader:
        time_Stamp = (row[0].split('='))[1]
        activity_set.append([float(time_Stamp),row[-1], map_activity(row[-1])])

# %% [markdown]
# ## Cut the data from the activity set, and find the vertical line of best fit to separate the points

# %%
# Now we can create an activity time track for each data point within
# the imu timeseries. We will have a list to store the numeric code and the string.
activity_timeseries = []
activity_string_timeseries = []
activity_idx = 0

# We need the time stamp for the start point
start_time = time_track[start_idx]

# The time track segment we are interested in 
time_track_segment = time_track[start_idx:end_idx]

#Add an 'end' activity - this book-ends the data
activity_set.append([time_track_segment[-1]-start_time, 'Standing'])

# Zero out the time track segment to make it match the video time
time_track_segment = np.array(time_track_segment)-start_time

fig, ax = plt.subplots(figsize=(20,10))
fig.suptitle("Raw Data - Clipped and Segmented for Each Activity")
ax.plot(time_track_segment,ax_set[start_idx:end_idx], color='r')
ax.plot(time_track_segment,ay_set[start_idx:end_idx], color='g')
ax.plot(time_track_segment,az_set[start_idx:end_idx], color='b')
ax.set_xlabel("Time Steps")
ax.set_ylabel("Value")

for act in np.array(list(zip(*activity_set)))[0,:]:
    ax.axvline(float(act))

# %% [markdown]
# ## Plot the end time steps to check the data

# %%
for imu_time_track_item in time_track_segment:
    current_time =  imu_time_track_item
    next_activity_ts = activity_set[activity_idx+1][0]
    
    # Here we need to move to the next activity in the annotations data if the current
    # IMU data point lies after the next annotation time stamp.
    if current_time > next_activity_ts:
        #Move to nex activity
        activity_idx = activity_idx + 1
        next_activity_ts = activity_set[activity_idx+1][0]
    
    
    activity_timeseries.append(activity_set[activity_idx][2])
    activity_string_timeseries.append(activity_set[activity_idx][1])

# %% [markdown]
# ## Plot a histogram to visualise the distribution

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.hist(activity_timeseries,bins=[-0.5,0.5,1.5,2.5,3.5,4.5], rwidth=0.95)
ax.set_title("Activity Frequency Distribution")
ax.set_ylabel("Activity Count")
ax.set_xticklabels(["", "Standing", "Walking", "Jogging", "Side-Step", "Running"])
# Out:
# <div id='cdbfa573-f19d-42a0-9ef2-131b36863f4e'></div>
# C:\Users\quinc\AppData\Local\Temp\ipykernel_17920\2634442597.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["", "Standing", "Walking", "Jogging", "Side-Step", "Running"])
# [Text(-1.0, 0, ''),
#  Text(0.0, 0, 'Standing'),
#  Text(1.0, 0, 'Walking'),
#  Text(2.0, 0, 'Jogging'),
#  Text(3.0, 0, 'Side-Step'),
#  Text(4.0, 0, 'Running'),
#  Text(5.0, 0, '')]

# %% [markdown]
# ## Set the x, y, z sets to the range of start to finish data

# %%
#We are only interested in the video window
ax_set = ax_set[start_idx:end_idx]
ay_set = ay_set[start_idx:end_idx]
az_set = az_set[start_idx:end_idx]
gx_set = gx_set[start_idx:end_idx]
gy_set = gy_set[start_idx:end_idx]
gz_set = gz_set[start_idx:end_idx]

# %% [markdown]
# ## Calculate the Signal Magnitude Area, and the Average Intensity for each label.
# ## Store the data into features, a target set for the training and testing data based on a 1 second interval from the video window

# %%
feature_set = []
target_set  = []            
window_size = 1.0

for t in range(int(time_track_segment[0]),int(time_track_segment[-1])):
    if not t+window_size in time_track_segment or not t in time_track_segment:
        continue
        
    

    #The index function finds the index of the first occurrence of the data
    window_start_idx = list(time_track_segment).index(t)
    window_end_idx = list(time_track_segment).index(t+window_size)
    ax_window = ax_set[window_start_idx:window_end_idx]
    ay_window = ay_set[window_start_idx:window_end_idx]
    az_window = az_set[window_start_idx:window_end_idx]
    gx_window = gx_set[window_start_idx:window_end_idx]
    gy_window = gy_set[window_start_idx:window_end_idx]
    gz_window = gz_set[window_start_idx:window_end_idx]

    #activity that will be assigned to the set of features
    activity_code = activity_timeseries[window_start_idx]
    
    # Now we can build features from the data window
    # Mean
    mu_ax, mu_ay, mu_az = statistics.mean(ax_window), statistics.mean(ay_window), statistics.mean(az_window)
    mu_gx, mu_gy, mu_gz = statistics.mean(gx_window), statistics.mean(gy_window), statistics.mean(gz_window)

    # Max
    max_ax, max_ay, max_az = max(ax_window), max(ay_window), max(az_window)
    max_gx, max_gy, max_gz = max(gx_window), max(gy_window), max(gz_window)

    # Min
    min_ax, min_ay, min_az = min(ax_window), min(ay_window), min(az_window)
    min_gx, min_gy, min_gz = min(gx_window), min(gy_window), min(gz_window)

    # Sum
    ax_abs_sum, ay_abs_sum, az_abs_sum = 0, 0, 0
    gx_abs_sum, gy_abs_sum, gz_abs_sum = 0, 0, 0

    # Sum of sqrt
    a_sum_sq = 0
    g_sum_sq = 0
    
        
    for i in range(0, len(ax_window)):

        # Add up the absolute values for the SMA
        ax_abs_sum = ax_abs_sum + abs(ax_window[i])
        ay_abs_sum = ay_abs_sum + abs(ay_window[i])
        az_abs_sum = az_abs_sum + abs(az_window[i])

        gx_abs_sum = gx_abs_sum + abs(gx_window[i])
        gy_abs_sum = gy_abs_sum + abs(gy_window[i])
        gz_abs_sum = gz_abs_sum + abs(gz_window[i])


        a_sum_sq = ((ax_window[i]**2) + (ay_window[i]**2) + (az_window[i]**2)) + a_sum_sq
        g_sum_sq = ((gx_window[i]**2) + (gy_window[i]**2) + (gz_window[i]**2)) + g_sum_sq

    # Signal Magnitude area    
    a_sma = (ax_abs_sum + ay_abs_sum + az_abs_sum) / len(ax_window)
    g_sma = (gx_abs_sum + gy_abs_sum + gz_abs_sum) / len(ax_window)

    # Average intensity
    a_av_intensity = math.sqrt(a_sum_sq) / len(ax_window)
    g_av_intensity = math.sqrt(g_sum_sq) / len(ax_window)


    feature_row = [mu_ax, mu_ay, mu_az, mu_gx, mu_gy, mu_gz,
                   max_ax, max_ay, max_az, max_gx, max_gy, max_gz,
                   min_ax, min_ay, min_az, min_gx, min_gy, min_gz,
                   a_sma, g_sma, a_av_intensity, g_av_intensity]

    feature_set.append(feature_row)
    target_set.append(activity_code)

# %% [markdown]
# ## Visualise the data

# %%
# Lets visualise some of the features just out of interest - we will look at the SMA and AI

fig, ax = plt.subplots(figsize=(20,10))
fig.suptitle("Example Features After Feature Engineering")
ax.plot(range(1,705),np.array(feature_set)[:,18], color='r')
ax.plot(range(1,705),np.array(feature_set)[:,19], color='g')
ax.plot(range(1,705),np.array(feature_set)[:,20], color='b')
ax.plot(range(1,705),np.array(feature_set)[:,21], color='c')
ax.set_xlabel("Time Steps")
ax.set_ylabel("Value")

# Plot the location of the activity transitions just to sanity check the data
#for act in np.array(list(zip(*activity_set)))[0,:]:
#    ax.axvline(float(act), alpha=0.5)

# REMOVED ACTIVITY SEGMENT LINES, DONT LINE UP PROPERLY
# Out:
# <div id='9bdcc3eb-7e42-433a-985f-0aab363ed8bb'></div>
# Text(0, 0.5, 'Value')

# %% [markdown]
# # *** Helper functions ***

# %% [markdown]
# ## Create a re-usable function to plot ROC Curves for each of the classifiers

# %%
def plot_roc_curve(function=None):
        nclasses = 3
        classifier = function
        x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=.2)
        classifier.fit(x_test, y_test)
        #x = feature_set                                                                                                    # variable not used
        y_score = classifier.predict_proba(x_test)
        y_test_bin = preprocessing.label_binarize(y_test, classes=[0, 1, 2, 3, 4])
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(nclasses):
            fpr[i], tpr[i], _ = metrics.roc_curve(y_test_bin[:, i], y_score[:, i])
            roc_auc[i] = metrics.auc(fpr[i], tpr[i])
        fig, ax = plt.subplots(figsize=(5, 5))
        colors = ['cyan', 'magenta', 'purple', 'blue', 'pink']
        plt.plot([0,1], [0,1], "r--")
        for i, color in zip(range(nclasses), colors):
            plt.plot(fpr[i], tpr[i], color=color,
                     label='ROC curve of class {0} (area = {1:0.2f})'
                           ''.format(i, roc_auc[i]))
        ax.set_xlabel("False Positives")
        ax.set_ylabel("True Positives")
        ax.set_title("ROC Curve of Classifications")
        ax.legend(["y=x", "Walking", "Standing", "Running", "Side-Step", "Jogging"])
        plt.show()

# %% [markdown]
# ## Create a function to find the best test and train split for the data

# %%
classifiers = ["Standing", "Walking", "Jogging", "Side-Step", "Running"]

c_names = [[i] for i in classifiers]

# Feature names for the tree.
labels = ["Mean Ax", "Mean Ay", "Mean Az","Mean Gx", "Mean Gy", "Mean Gz",
           "Max Ax", "Max Ay", "Max Az","Max Gx", "Max Gy", "Max Gz", 
           "Min Ax", "Min Ay", "Min Az","Min Gx", "Min Gy", "Min Gz",
           "Acceleration SMA", "Gyroscope SMA" , "Acceleration AI", "Gyroscope AI"]

f_names = [[i] for i in labels]
        
        
def get_training_split():
    test_sizes = [round(float(i * .1), 2) for i in range(1, 9)].__reversed__()
    test_sizes = list(test_sizes)
    knn = neighbors.KNeighborsClassifier(n_neighbors=4)
    plt.figure()

    for test_size in test_sizes:
        scores = []
        for i in range(1, 100):
            x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=1 - test_size)
            knn.fit(x_train, y_train)
            scores.append(knn.score(x_test, y_test))
        plt.plot(test_size, np.mean(scores), "r+")
    plt.plot()
    plt.xlabel("training % split")
    plt.ylabel("predictions")
    plt.show()

# %% [markdown]
# # *** KNN Classifier ***

# %% [markdown]
# ## Create a function to find the best neighbors for the KNN Classifier

# %%
def find_knn_neighbours():
    k_range = range(1,20)
    scores = []
    max_score = []
    for k in k_range:
        x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set)
        knn = neighbors.KNeighborsClassifier(n_neighbors=k)
        knn.fit(x_train, y_train)
        scores.append(knn.score(x_test, y_test))
        max_score.append([(knn.score(x_test, y_test)), k]) 
    plt.figure()
    plt.xlabel("k neighbours")
    plt.ylabel("predictions")
    plt.scatter(k_range, scores)
    plt.grid()
    plt.xticks([i for i in range(0, 35, 5)])
    plt.xlim([0, 30])
    plt.ylim([0, 1])
    plt.show()
    max_score = max(max_score[1])
    return max_score

# %% [markdown]
# ## Train and test the data based on the KNN Classifier and produce plots to visually inspect the performance

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=.2, random_state=42)

# Set the number neighbours to use in the classifier
n_neighbors = find_knn_neighbours()

# we create an instance of Neighbours Classifier and fit the data.
clf = neighbors.KNeighborsClassifier(n_neighbors, weights='uniform')

# Train the model
clf.fit(X_train, y_train)

# Return the predictions for the 3-Fold cross-validation
y_predicted = cross_val_predict(clf, X_train,y_train, cv=3)

# Return the predictions for the test set
y_test_predicted = clf.predict(X_test)

# Construct the confusion matrices
conf_mat_train = confusion_matrix(y_train, y_predicted)
conf_mat_test = confusion_matrix(y_test, y_test_predicted)

# store categorical accuracy for comparison to other models
knn_cat_accuracy = list(conf_mat_test.diagonal()/conf_mat_test.sum(axis=1))

# Print out the recall, precision and F1 scores
# There will be a value for each class
# CV Train
print("CV Train Recall:\t", recall_score(y_train,y_predicted,average=None))
print("CV Train Precision:\t",precision_score(y_train,y_predicted,average=None))
print("CV Train F1 Score:\t",f1_score(y_train,y_predicted,average=None))

# Test
print("Test Recall:\t\t",recall_score(y_test,y_test_predicted,average=None))
print("Test Precision:\t\t",precision_score(y_test,y_test_predicted,average=None))
print("Test F1 Score:\t\t",f1_score(y_test,y_test_predicted,average=None))

# Plot the confusion matrices
fig, ax = plt.subplots()
disp = plot_cm(clf, X_train, y_train,
                                 display_labels=['Walking','Jogging','Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

ax.set_title('3-Fold Training')

fig, ax = plt.subplots()
disp = plot_cm(clf, X_test, y_test,
                                 display_labels=['Walking', 'Jogging', 'Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
plot_roc_curve(clf)
# Out:
# <div id='4a40ee17-7f58-4a8e-b936-e9c4a65b8c56'></div>
# CV Train Recall:	 [0.95833333 0.95364238 0.96226415 0.84444444 0.76923077]
# CV Train Precision:	 [0.80232558 0.90566038 0.90532544 0.96202532 1.        ]
# CV Train F1 Score:	 [0.87341772 0.92903226 0.93292683 0.89940828 0.86956522]
# Test Recall:		 [0.89473684 0.95555556 0.9        0.95833333 1.        ]
# Test Precision:		 [0.77272727 0.91489362 1.         1.         1.        ]
# Test F1 Score:		 [0.82926829 0.93478261 0.94736842 0.9787234  1.        ]
# <div id='f7802e77-7227-487f-9c31-b840c532bac1'></div>
# C:\JupyterLab\resources\jlab_server\envs\workspace\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <div id='f99b12e4-47cb-455d-98c3-aac278f524a9'></div>
# C:\JupyterLab\resources\jlab_server\envs\workspace\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <div id='136a2df7-1ac4-457c-92f0-39913bb7697f'></div>

# %% [markdown]
# ## Create a function to get the best training split for the RandomForestClassifier

# %%
def get_training_split_forrest():
    test_sizes = [round(float(i * .1), 2) for i in range(1, 9)].__reversed__()
    test_sizes = list(test_sizes)
    clf = RandomForestClassifier()
    plt.figure()

    for test_size in test_sizes:
        scores = []
        for i in range(1, 100):
            x_train, x_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=1 - test_size)
            clf.fit(x_train, y_train)
            scores.append(clf.score(x_test, y_test))
        plt.plot(test_size, np.mean(scores), "r+")
    plt.plot()
    plt.xlabel("training % split")
    plt.ylabel("predictions")
    plt.show()

# %matplotlib notebook
get_training_split()
# Out:
# <div id='768f6557-4e7e-4fc9-816c-194de5024619'></div>

# %% [markdown]
# # *** Random Forest Classifier ***

# %% [markdown]
# ## Test and train the Random Forest Classifier and plot graphs to visualise the data

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, test_size=.2, random_state=42)

clf = RandomForestClassifier()

clf.fit(X_train, y_train)
# Return the predictions for the 3-Fold cross-validation
y_predicted = cross_val_predict(clf, X_train,y_train, cv=3)
# Return the predictions for the test set
y_test_predicted = clf.predict(X_test)
# Construct the confusion matrices
conf_mat_train = confusion_matrix(y_train, y_predicted)
conf_mat_test = confusion_matrix(y_test, y_test_predicted)

# store categorical accuracy for comparison to other models
rf_cat_accuracy = list(conf_mat_test.diagonal()/conf_mat_test.sum(axis=1))

# Print out the recall, precision and F1 scores
# There will be a value for each class
# CV Train
print("CV Train Recall:\t", recall_score(y_train,y_predicted,average=None))
print("CV Train Precision:\t",precision_score(y_train,y_predicted,average=None))
print("CV Train F1 Score:\t",f1_score(y_train,y_predicted,average=None))

# Test
print("Test Recall:\t\t",recall_score(y_test,y_test_predicted,average=None))
print("Test Precision:\t\t",precision_score(y_test,y_test_predicted,average=None))
print("Test F1 Score:\t\t",f1_score(y_test,y_test_predicted,average=None))

# Plot the confusion matrices using the pretty functions
fig, ax = plt.subplots()
disp = plot_cm(clf, X_train, y_train,
                                 display_labels=['Walking','Jogging','Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

ax.set_title('3-Fold Training')

fig, ax = plt.subplots()
disp = plot_cm(clf, X_test, y_test,
                                 display_labels=['Walking', 'Jogging', 'Running', 'Side-Step', 'Standing'],
                                 cmap=plt.cm.Blues,ax=ax)
# Rotate the labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
# Out:
# CV Train Recall:	 [0.93055556 0.96688742 0.97484277 0.88888889 0.91208791]
# CV Train Precision:	 [0.87012987 0.89570552 0.97484277 0.98765432 1.        ]
# CV Train F1 Score:	 [0.89932886 0.92993631 0.97484277 0.93567251 0.95402299]
# Test Recall:		 [0.89473684 0.97777778 0.925      1.         1.        ]
# Test Precision:		 [0.89473684 0.91666667 1.         1.         1.        ]
# Test F1 Score:		 [0.89473684 0.94623656 0.96103896 1.         1.        ]
# <div id='8725cae8-990b-4214-a2be-04ded283eddc'></div>
# C:\JupyterLab\resources\jlab_server\envs\workspace\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <div id='3b40c00a-ef2b-4858-b48e-d63c62effd8c'></div>
# C:\JupyterLab\resources\jlab_server\envs\workspace\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # *** Stochastic Gradient Descent Classifier ***

# %% [markdown]
# ## Split and scale data

# %%
# split train and test sets
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, random_state=42)

# scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Train model and optimise hyper parameters through iteration

# %%
from sklearn.metrics import recall_score, precision_score

best_mean_f1 = 0
best_alpha = 0
best_max_iter = 0

alpha_test_values = [0.001,0.005,0.01,0.05]
max_iter_test_values = [100,250,500]

# Iterate through hyper parameter options
for alpha in alpha_test_values:
    for iterations in max_iter_test_values:

        # train classifier
        sgd = SGDClassifier(alpha=alpha, max_iter=iterations, random_state=42)
        sgd.fit(X_train_scaled, y_train)

        # predict using 3-fold cross validation
        y_train_predicted = cross_val_predict(sgd, X_train_scaled, y_train, cv=3)                # TODO: DO I NEED TO SPECIFY FEATURE COLUMNS HERE ??


        current_f1 = np.mean(f1_score(y_train, y_train_predicted, average=None))
        if current_f1 > best_mean_f1:
            best_mean_f1 = current_f1
            best_alpha = alpha
            best_max_iter = iterations
            best_sgd = sgd
            best_y_train_predicted = y_train_predicted


# predict using best SGD classifier
y_test_predicted = best_sgd.predict(X_test_scaled)

print("Hyper Parameter Combination")
print("Best alpha: ", best_alpha)
print("Best max_iter: ", best_max_iter, "\n")
print("CV Train Recall: \t\t", recall_score(y_train, best_y_train_predicted, average=None))
print("CV Train Precision: \t", precision_score(y_train, best_y_train_predicted, average=None))
print("CV Train F1: \t\t\t", f1_score(y_train, best_y_train_predicted, average=None))
print("Test Recall: \t\t\t", recall_score(y_test, y_test_predicted, average=None))
print("Test Precision: \t\t", precision_score(y_test, y_test_predicted, average=None))
print("Test F1: \t\t\t\t", f1_score(y_test, y_test_predicted, average=None))
# Out:
# Hyper Parameter Combination
# Best alpha:  0.01
# Best max_iter:  100
#
# CV Train Recall: 		 [0.92647059 0.95       0.98648649 0.90588235 0.88505747]
# CV Train Precision: 	 [0.92647059 0.9109589  0.94805195 0.95061728 0.97468354]
# CV Train F1: 			 [0.92647059 0.93006993 0.96688742 0.92771084 0.92771084]
# Test Recall: 			 [0.91304348 0.94642857 0.96078431 0.89655172 1.        ]
# Test Precision: 		 [0.91304348 0.92982456 0.94230769 1.         0.94444444]
# Test F1: 				 [0.91304348 0.9380531  0.95145631 0.94545455 0.97142857]

# %% [markdown]
# ## Plot Confusion Matrices

# %%
# plot confusion matrix for train set
fig, ax = plt.subplots()
ax.set_title("Train")
disp = plot_cm(best_sgd, X_train_scaled, y_train,
                             display_labels=["Standing", "Walking", "Jogging", "Side-Step", "Running"],
                             cmap=plt.cm.Blues, ax=ax)

# plot confusion matrix for test set
fig, ax = plt.subplots()
ax.set_title("Test")
disp = plot_cm(best_sgd, X_test_scaled, y_test,
                             display_labels=["Standing", "Walking", "Jogging", "Side-Step", "Running"],
                             cmap=plt.cm.Blues, ax=ax)

# Store categorical accuracy for comparison to other models
conf_mat_test = confusion_matrix(y_test, y_test_predicted)
sgd_cat_accuracy = list(conf_mat_test.diagonal()/conf_mat_test.sum(axis=1))
# Out:
# <div id='63af99b4-8c44-47f4-b200-c94d8a8e9cb1'></div>
# C:\JupyterLab\resources\jlab_server\envs\workspace\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <div id='4024d00c-6e5f-4217-aabc-b24106049249'></div>
# C:\JupyterLab\resources\jlab_server\envs\workspace\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # *** Neural Network ***

# %% [markdown]
# ## Split and scale data

# %%
# split train and test sets
X_train, X_test, y_train, y_test = train_test_split(feature_set, target_set, random_state=42)

# convert to numpy arrays
X_train = np.asarray(X_train)
y_train = np.asarray(y_train)
X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

# apply MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# convert target classes to categorical array for neural network
y_train_cat_array = to_categorical(y_train, num_classes=5)
y_test_cat_array = to_categorical(y_test, num_classes=5)

# %% [markdown]
# ## Build and train NN model

# %%
# NN input layer size
input_size = len(X_test_scaled[0])
# set random state
tf.random.set_seed(42)
# declare variable for activation function to test various functions
activation_function = 'relu'

# build model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(input_size, activation=activation_function),
    tf.keras.layers.Dense(128, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(128, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(128, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(64, activation=activation_function),
    tf.keras.layers.Dropout(rate=0.25, seed=42),
    tf.keras.layers.Dense(32, activation=activation_function),
    tf.keras.layers.Dense(5, activation='softmax')
])

# compile model
model.compile(
    loss=tf.keras.losses.categorical_crossentropy,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['categorical_accuracy']
)

# train model
history = model.fit(
    X_train_scaled,
    y_train_cat_array,
    epochs=250,
    validation_data=(X_test_scaled, y_test_cat_array),      # Ideally a validation split would be used here, but for our example the test data has been used for validation
    batch_size=32
)
# Out:
# Epoch 1/250
# 17/17 [==============================] - 1s 11ms/step - loss: 1.6043 - categorical_accuracy: 0.2500 - val_loss: 1.6053 - val_categorical_accuracy: 0.2898
# Epoch 2/250
# 17/17 [==============================] - 0s 4ms/step - loss: 1.5984 - categorical_accuracy: 0.2708 - val_loss: 1.5955 - val_categorical_accuracy: 0.2898
# Epoch 3/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5892 - categorical_accuracy: 0.2936 - val_loss: 1.5837 - val_categorical_accuracy: 0.2898
# Epoch 4/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5770 - categorical_accuracy: 0.2879 - val_loss: 1.5705 - val_categorical_accuracy: 0.2898
# Epoch 5/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5694 - categorical_accuracy: 0.2879 - val_loss: 1.5554 - val_categorical_accuracy: 0.2898
# Epoch 6/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5538 - categorical_accuracy: 0.2784 - val_loss: 1.5370 - val_categorical_accuracy: 0.2898
# Epoch 7/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5522 - categorical_accuracy: 0.2879 - val_loss: 1.5166 - val_categorical_accuracy: 0.2898
# Epoch 8/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5364 - categorical_accuracy: 0.2992 - val_loss: 1.4972 - val_categorical_accuracy: 0.2955
# Epoch 9/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5149 - categorical_accuracy: 0.3295 - val_loss: 1.4727 - val_categorical_accuracy: 0.3523
# Epoch 10/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5076 - categorical_accuracy: 0.3295 - val_loss: 1.4418 - val_categorical_accuracy: 0.5284
# Epoch 11/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.4798 - categorical_accuracy: 0.3826 - val_loss: 1.4083 - val_categorical_accuracy: 0.5625
# Epoch 12/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.4591 - categorical_accuracy: 0.3750 - val_loss: 1.3737 - val_categorical_accuracy: 0.5568
# Epoch 13/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.4337 - categorical_accuracy: 0.4186 - val_loss: 1.3281 - val_categorical_accuracy: 0.5739
# Epoch 14/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3857 - categorical_accuracy: 0.4508 - val_loss: 1.2778 - val_categorical_accuracy: 0.5795
# Epoch 15/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3594 - categorical_accuracy: 0.5000 - val_loss: 1.2204 - val_categorical_accuracy: 0.5795
# Epoch 16/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3067 - categorical_accuracy: 0.4830 - val_loss: 1.1623 - val_categorical_accuracy: 0.5795
# Epoch 17/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.2310 - categorical_accuracy: 0.5246 - val_loss: 1.0945 - val_categorical_accuracy: 0.5795
# Epoch 18/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.1919 - categorical_accuracy: 0.5246 - val_loss: 1.0215 - val_categorical_accuracy: 0.5852
# Epoch 19/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.1367 - categorical_accuracy: 0.5682 - val_loss: 0.9472 - val_categorical_accuracy: 0.6761
# Epoch 20/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.0486 - categorical_accuracy: 0.5985 - val_loss: 0.8713 - val_categorical_accuracy: 0.6989
# Epoch 21/250
# 17/17 [==============================] - 0s 3ms/step - loss: 1.0023 - categorical_accuracy: 0.6212 - val_loss: 0.8039 - val_categorical_accuracy: 0.8182
# Epoch 22/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.9502 - categorical_accuracy: 0.6742 - val_loss: 0.7362 - val_categorical_accuracy: 0.8409
# Epoch 23/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8949 - categorical_accuracy: 0.6989 - val_loss: 0.6673 - val_categorical_accuracy: 0.8580
# Epoch 24/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8540 - categorical_accuracy: 0.7367 - val_loss: 0.6110 - val_categorical_accuracy: 0.8580
# Epoch 25/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7790 - categorical_accuracy: 0.7879 - val_loss: 0.5522 - val_categorical_accuracy: 0.8580
# Epoch 26/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7142 - categorical_accuracy: 0.7917 - val_loss: 0.5043 - val_categorical_accuracy: 0.8580
# Epoch 27/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7101 - categorical_accuracy: 0.7841 - val_loss: 0.4659 - val_categorical_accuracy: 0.8636
# Epoch 28/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6470 - categorical_accuracy: 0.8352 - val_loss: 0.4269 - val_categorical_accuracy: 0.8636
# Epoch 29/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6195 - categorical_accuracy: 0.8390 - val_loss: 0.3927 - val_categorical_accuracy: 0.8920
# Epoch 30/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5882 - categorical_accuracy: 0.8447 - val_loss: 0.3792 - val_categorical_accuracy: 0.8636
# Epoch 31/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5620 - categorical_accuracy: 0.8352 - val_loss: 0.3578 - val_categorical_accuracy: 0.8920
# Epoch 32/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5405 - categorical_accuracy: 0.8428 - val_loss: 0.3496 - val_categorical_accuracy: 0.8864
# Epoch 33/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4712 - categorical_accuracy: 0.8902 - val_loss: 0.3316 - val_categorical_accuracy: 0.9034
# Epoch 34/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4794 - categorical_accuracy: 0.8598 - val_loss: 0.3130 - val_categorical_accuracy: 0.9091
# Epoch 35/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4741 - categorical_accuracy: 0.8712 - val_loss: 0.3113 - val_categorical_accuracy: 0.9091
# Epoch 36/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4559 - categorical_accuracy: 0.8655 - val_loss: 0.3022 - val_categorical_accuracy: 0.9148
# Epoch 37/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4336 - categorical_accuracy: 0.8655 - val_loss: 0.2826 - val_categorical_accuracy: 0.9148
# Epoch 38/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4277 - categorical_accuracy: 0.8902 - val_loss: 0.2806 - val_categorical_accuracy: 0.9205
# Epoch 39/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4191 - categorical_accuracy: 0.8920 - val_loss: 0.2815 - val_categorical_accuracy: 0.9148
# Epoch 40/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3893 - categorical_accuracy: 0.8977 - val_loss: 0.2623 - val_categorical_accuracy: 0.9261
# Epoch 41/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3977 - categorical_accuracy: 0.8864 - val_loss: 0.2629 - val_categorical_accuracy: 0.9261
# Epoch 42/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3674 - categorical_accuracy: 0.9015 - val_loss: 0.2692 - val_categorical_accuracy: 0.9205
# Epoch 43/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3541 - categorical_accuracy: 0.9053 - val_loss: 0.2497 - val_categorical_accuracy: 0.9318
# Epoch 44/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3547 - categorical_accuracy: 0.9110 - val_loss: 0.2407 - val_categorical_accuracy: 0.9261
# Epoch 45/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3574 - categorical_accuracy: 0.8939 - val_loss: 0.2406 - val_categorical_accuracy: 0.9261
# Epoch 46/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3497 - categorical_accuracy: 0.9072 - val_loss: 0.2444 - val_categorical_accuracy: 0.9375
# Epoch 47/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3475 - categorical_accuracy: 0.9110 - val_loss: 0.2431 - val_categorical_accuracy: 0.9148
# Epoch 48/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3312 - categorical_accuracy: 0.9110 - val_loss: 0.2407 - val_categorical_accuracy: 0.9261
# Epoch 49/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3205 - categorical_accuracy: 0.9167 - val_loss: 0.2442 - val_categorical_accuracy: 0.9261
# Epoch 50/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3317 - categorical_accuracy: 0.9167 - val_loss: 0.2406 - val_categorical_accuracy: 0.9318
# Epoch 51/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3008 - categorical_accuracy: 0.9110 - val_loss: 0.2280 - val_categorical_accuracy: 0.9318
# Epoch 52/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3211 - categorical_accuracy: 0.9167 - val_loss: 0.2234 - val_categorical_accuracy: 0.9432
# Epoch 53/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3102 - categorical_accuracy: 0.9337 - val_loss: 0.2286 - val_categorical_accuracy: 0.9375
# Epoch 54/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3239 - categorical_accuracy: 0.9091 - val_loss: 0.2282 - val_categorical_accuracy: 0.9318
# Epoch 55/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3087 - categorical_accuracy: 0.9110 - val_loss: 0.2190 - val_categorical_accuracy: 0.9432
# Epoch 56/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3081 - categorical_accuracy: 0.9148 - val_loss: 0.2426 - val_categorical_accuracy: 0.9318
# Epoch 57/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2827 - categorical_accuracy: 0.9129 - val_loss: 0.2243 - val_categorical_accuracy: 0.9375
# Epoch 58/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2645 - categorical_accuracy: 0.9223 - val_loss: 0.2288 - val_categorical_accuracy: 0.9375
# Epoch 59/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2732 - categorical_accuracy: 0.9205 - val_loss: 0.2277 - val_categorical_accuracy: 0.9375
# Epoch 60/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2738 - categorical_accuracy: 0.9280 - val_loss: 0.2247 - val_categorical_accuracy: 0.9432
# Epoch 61/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2576 - categorical_accuracy: 0.9261 - val_loss: 0.2143 - val_categorical_accuracy: 0.9489
# Epoch 62/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2595 - categorical_accuracy: 0.9432 - val_loss: 0.2132 - val_categorical_accuracy: 0.9545
# Epoch 63/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2656 - categorical_accuracy: 0.9280 - val_loss: 0.2099 - val_categorical_accuracy: 0.9489
# Epoch 64/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2655 - categorical_accuracy: 0.9261 - val_loss: 0.2161 - val_categorical_accuracy: 0.9489
# Epoch 65/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2454 - categorical_accuracy: 0.9337 - val_loss: 0.2150 - val_categorical_accuracy: 0.9545
# Epoch 66/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2479 - categorical_accuracy: 0.9337 - val_loss: 0.2102 - val_categorical_accuracy: 0.9489
# Epoch 67/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2395 - categorical_accuracy: 0.9337 - val_loss: 0.2168 - val_categorical_accuracy: 0.9432
# Epoch 68/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2443 - categorical_accuracy: 0.9394 - val_loss: 0.2110 - val_categorical_accuracy: 0.9432
# Epoch 69/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2555 - categorical_accuracy: 0.9299 - val_loss: 0.2108 - val_categorical_accuracy: 0.9545
# Epoch 70/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2256 - categorical_accuracy: 0.9451 - val_loss: 0.2170 - val_categorical_accuracy: 0.9432
# Epoch 71/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2283 - categorical_accuracy: 0.9470 - val_loss: 0.2082 - val_categorical_accuracy: 0.9545
# Epoch 72/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2354 - categorical_accuracy: 0.9280 - val_loss: 0.2177 - val_categorical_accuracy: 0.9432
# Epoch 73/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2461 - categorical_accuracy: 0.9242 - val_loss: 0.2216 - val_categorical_accuracy: 0.9432
# Epoch 74/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2424 - categorical_accuracy: 0.9432 - val_loss: 0.2141 - val_categorical_accuracy: 0.9489
# Epoch 75/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2404 - categorical_accuracy: 0.9432 - val_loss: 0.2113 - val_categorical_accuracy: 0.9489
# Epoch 76/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2107 - categorical_accuracy: 0.9470 - val_loss: 0.2045 - val_categorical_accuracy: 0.9545
# Epoch 77/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2155 - categorical_accuracy: 0.9394 - val_loss: 0.2065 - val_categorical_accuracy: 0.9545
# Epoch 78/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2021 - categorical_accuracy: 0.9432 - val_loss: 0.2105 - val_categorical_accuracy: 0.9489
# Epoch 79/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2235 - categorical_accuracy: 0.9318 - val_loss: 0.2141 - val_categorical_accuracy: 0.9489
# Epoch 80/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2243 - categorical_accuracy: 0.9394 - val_loss: 0.2131 - val_categorical_accuracy: 0.9489
# Epoch 81/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2219 - categorical_accuracy: 0.9451 - val_loss: 0.2125 - val_categorical_accuracy: 0.9489
# Epoch 82/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2286 - categorical_accuracy: 0.9261 - val_loss: 0.2121 - val_categorical_accuracy: 0.9489
# Epoch 83/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2146 - categorical_accuracy: 0.9451 - val_loss: 0.2102 - val_categorical_accuracy: 0.9489
# Epoch 84/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2160 - categorical_accuracy: 0.9451 - val_loss: 0.2096 - val_categorical_accuracy: 0.9489
# Epoch 85/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2007 - categorical_accuracy: 0.9489 - val_loss: 0.2028 - val_categorical_accuracy: 0.9489
# Epoch 86/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2158 - categorical_accuracy: 0.9337 - val_loss: 0.2086 - val_categorical_accuracy: 0.9489
# Epoch 87/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1860 - categorical_accuracy: 0.9564 - val_loss: 0.2150 - val_categorical_accuracy: 0.9489
# Epoch 88/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2018 - categorical_accuracy: 0.9375 - val_loss: 0.2120 - val_categorical_accuracy: 0.9489
# Epoch 89/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2044 - categorical_accuracy: 0.9470 - val_loss: 0.2078 - val_categorical_accuracy: 0.9489
# Epoch 90/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1937 - categorical_accuracy: 0.9432 - val_loss: 0.2105 - val_categorical_accuracy: 0.9489
# Epoch 91/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2068 - categorical_accuracy: 0.9451 - val_loss: 0.2074 - val_categorical_accuracy: 0.9489
# Epoch 92/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1911 - categorical_accuracy: 0.9470 - val_loss: 0.2107 - val_categorical_accuracy: 0.9489
# Epoch 93/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1801 - categorical_accuracy: 0.9451 - val_loss: 0.2140 - val_categorical_accuracy: 0.9489
# Epoch 94/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1778 - categorical_accuracy: 0.9527 - val_loss: 0.2152 - val_categorical_accuracy: 0.9432
# Epoch 95/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1759 - categorical_accuracy: 0.9527 - val_loss: 0.2095 - val_categorical_accuracy: 0.9489
# Epoch 96/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1940 - categorical_accuracy: 0.9489 - val_loss: 0.2080 - val_categorical_accuracy: 0.9489
# Epoch 97/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1942 - categorical_accuracy: 0.9470 - val_loss: 0.2109 - val_categorical_accuracy: 0.9489
# Epoch 98/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1996 - categorical_accuracy: 0.9394 - val_loss: 0.2106 - val_categorical_accuracy: 0.9489
# Epoch 99/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1687 - categorical_accuracy: 0.9545 - val_loss: 0.2086 - val_categorical_accuracy: 0.9545
# Epoch 100/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1714 - categorical_accuracy: 0.9564 - val_loss: 0.2066 - val_categorical_accuracy: 0.9489
# Epoch 101/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1909 - categorical_accuracy: 0.9432 - val_loss: 0.2042 - val_categorical_accuracy: 0.9489
# Epoch 102/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1801 - categorical_accuracy: 0.9545 - val_loss: 0.2043 - val_categorical_accuracy: 0.9545
# Epoch 103/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1692 - categorical_accuracy: 0.9602 - val_loss: 0.2069 - val_categorical_accuracy: 0.9545
# Epoch 104/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1634 - categorical_accuracy: 0.9564 - val_loss: 0.2099 - val_categorical_accuracy: 0.9489
# Epoch 105/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1790 - categorical_accuracy: 0.9489 - val_loss: 0.2103 - val_categorical_accuracy: 0.9489
# Epoch 106/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1844 - categorical_accuracy: 0.9432 - val_loss: 0.2064 - val_categorical_accuracy: 0.9545
# Epoch 107/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1840 - categorical_accuracy: 0.9489 - val_loss: 0.2127 - val_categorical_accuracy: 0.9545
# Epoch 108/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1491 - categorical_accuracy: 0.9621 - val_loss: 0.2147 - val_categorical_accuracy: 0.9545
# Epoch 109/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1751 - categorical_accuracy: 0.9527 - val_loss: 0.2149 - val_categorical_accuracy: 0.9489
# Epoch 110/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1590 - categorical_accuracy: 0.9583 - val_loss: 0.2097 - val_categorical_accuracy: 0.9489
# Epoch 111/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1660 - categorical_accuracy: 0.9527 - val_loss: 0.2102 - val_categorical_accuracy: 0.9489
# Epoch 112/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1581 - categorical_accuracy: 0.9545 - val_loss: 0.2060 - val_categorical_accuracy: 0.9489
# Epoch 113/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1592 - categorical_accuracy: 0.9602 - val_loss: 0.2130 - val_categorical_accuracy: 0.9489
# Epoch 114/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1606 - categorical_accuracy: 0.9545 - val_loss: 0.2137 - val_categorical_accuracy: 0.9489
# Epoch 115/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1668 - categorical_accuracy: 0.9527 - val_loss: 0.2122 - val_categorical_accuracy: 0.9489
# Epoch 116/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1672 - categorical_accuracy: 0.9470 - val_loss: 0.2080 - val_categorical_accuracy: 0.9545
# Epoch 117/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1542 - categorical_accuracy: 0.9564 - val_loss: 0.2021 - val_categorical_accuracy: 0.9489
# Epoch 118/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1437 - categorical_accuracy: 0.9621 - val_loss: 0.2108 - val_categorical_accuracy: 0.9489
# Epoch 119/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1714 - categorical_accuracy: 0.9640 - val_loss: 0.2110 - val_categorical_accuracy: 0.9489
# Epoch 120/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1578 - categorical_accuracy: 0.9508 - val_loss: 0.2208 - val_categorical_accuracy: 0.9489
# Epoch 121/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1623 - categorical_accuracy: 0.9451 - val_loss: 0.2158 - val_categorical_accuracy: 0.9545
# Epoch 122/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1691 - categorical_accuracy: 0.9583 - val_loss: 0.2103 - val_categorical_accuracy: 0.9545
# Epoch 123/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1614 - categorical_accuracy: 0.9564 - val_loss: 0.2066 - val_categorical_accuracy: 0.9489
# Epoch 124/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1557 - categorical_accuracy: 0.9640 - val_loss: 0.2089 - val_categorical_accuracy: 0.9489
# Epoch 125/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1495 - categorical_accuracy: 0.9621 - val_loss: 0.2104 - val_categorical_accuracy: 0.9545
# Epoch 126/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1652 - categorical_accuracy: 0.9602 - val_loss: 0.2062 - val_categorical_accuracy: 0.9545
# Epoch 127/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1786 - categorical_accuracy: 0.9583 - val_loss: 0.2084 - val_categorical_accuracy: 0.9545
# Epoch 128/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1659 - categorical_accuracy: 0.9508 - val_loss: 0.2046 - val_categorical_accuracy: 0.9545
# Epoch 129/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1322 - categorical_accuracy: 0.9621 - val_loss: 0.2094 - val_categorical_accuracy: 0.9489
# Epoch 130/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1515 - categorical_accuracy: 0.9564 - val_loss: 0.2085 - val_categorical_accuracy: 0.9545
# Epoch 131/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1564 - categorical_accuracy: 0.9527 - val_loss: 0.2057 - val_categorical_accuracy: 0.9489
# Epoch 132/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1574 - categorical_accuracy: 0.9545 - val_loss: 0.2098 - val_categorical_accuracy: 0.9489
# Epoch 133/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1621 - categorical_accuracy: 0.9564 - val_loss: 0.2116 - val_categorical_accuracy: 0.9489
# Epoch 134/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1452 - categorical_accuracy: 0.9621 - val_loss: 0.2059 - val_categorical_accuracy: 0.9545
# Epoch 135/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1565 - categorical_accuracy: 0.9583 - val_loss: 0.2126 - val_categorical_accuracy: 0.9545
# Epoch 136/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1440 - categorical_accuracy: 0.9621 - val_loss: 0.2125 - val_categorical_accuracy: 0.9545
# Epoch 137/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1356 - categorical_accuracy: 0.9602 - val_loss: 0.2060 - val_categorical_accuracy: 0.9545
# Epoch 138/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1234 - categorical_accuracy: 0.9640 - val_loss: 0.2092 - val_categorical_accuracy: 0.9545
# Epoch 139/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1503 - categorical_accuracy: 0.9583 - val_loss: 0.2070 - val_categorical_accuracy: 0.9545
# Epoch 140/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1402 - categorical_accuracy: 0.9583 - val_loss: 0.2018 - val_categorical_accuracy: 0.9545
# Epoch 141/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1567 - categorical_accuracy: 0.9602 - val_loss: 0.2079 - val_categorical_accuracy: 0.9602
# Epoch 142/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1515 - categorical_accuracy: 0.9583 - val_loss: 0.2077 - val_categorical_accuracy: 0.9602
# Epoch 143/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1447 - categorical_accuracy: 0.9583 - val_loss: 0.2099 - val_categorical_accuracy: 0.9489
# Epoch 144/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1296 - categorical_accuracy: 0.9583 - val_loss: 0.2051 - val_categorical_accuracy: 0.9545
# Epoch 145/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1495 - categorical_accuracy: 0.9545 - val_loss: 0.2055 - val_categorical_accuracy: 0.9545
# Epoch 146/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1568 - categorical_accuracy: 0.9545 - val_loss: 0.2044 - val_categorical_accuracy: 0.9545
# Epoch 147/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1444 - categorical_accuracy: 0.9564 - val_loss: 0.2093 - val_categorical_accuracy: 0.9545
# Epoch 148/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1505 - categorical_accuracy: 0.9527 - val_loss: 0.2098 - val_categorical_accuracy: 0.9545
# Epoch 149/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1342 - categorical_accuracy: 0.9678 - val_loss: 0.2022 - val_categorical_accuracy: 0.9545
# Epoch 150/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1482 - categorical_accuracy: 0.9564 - val_loss: 0.2004 - val_categorical_accuracy: 0.9545
# Epoch 151/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1419 - categorical_accuracy: 0.9640 - val_loss: 0.2043 - val_categorical_accuracy: 0.9545
# Epoch 152/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1431 - categorical_accuracy: 0.9545 - val_loss: 0.2103 - val_categorical_accuracy: 0.9545
# Epoch 153/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1441 - categorical_accuracy: 0.9583 - val_loss: 0.2092 - val_categorical_accuracy: 0.9545
# Epoch 154/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1377 - categorical_accuracy: 0.9602 - val_loss: 0.2060 - val_categorical_accuracy: 0.9545
# Epoch 155/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1485 - categorical_accuracy: 0.9564 - val_loss: 0.2078 - val_categorical_accuracy: 0.9545
# Epoch 156/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1236 - categorical_accuracy: 0.9602 - val_loss: 0.2111 - val_categorical_accuracy: 0.9545
# Epoch 157/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1256 - categorical_accuracy: 0.9678 - val_loss: 0.2040 - val_categorical_accuracy: 0.9602
# Epoch 158/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1272 - categorical_accuracy: 0.9602 - val_loss: 0.2107 - val_categorical_accuracy: 0.9545
# Epoch 159/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1372 - categorical_accuracy: 0.9621 - val_loss: 0.2122 - val_categorical_accuracy: 0.9602
# Epoch 160/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1321 - categorical_accuracy: 0.9583 - val_loss: 0.2070 - val_categorical_accuracy: 0.9545
# Epoch 161/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1293 - categorical_accuracy: 0.9678 - val_loss: 0.2036 - val_categorical_accuracy: 0.9602
# Epoch 162/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1360 - categorical_accuracy: 0.9640 - val_loss: 0.2044 - val_categorical_accuracy: 0.9545
# Epoch 163/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1426 - categorical_accuracy: 0.9602 - val_loss: 0.2084 - val_categorical_accuracy: 0.9545
# Epoch 164/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1390 - categorical_accuracy: 0.9640 - val_loss: 0.2084 - val_categorical_accuracy: 0.9602
# Epoch 165/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1547 - categorical_accuracy: 0.9678 - val_loss: 0.2070 - val_categorical_accuracy: 0.9545
# Epoch 166/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1350 - categorical_accuracy: 0.9621 - val_loss: 0.2043 - val_categorical_accuracy: 0.9545
# Epoch 167/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1192 - categorical_accuracy: 0.9640 - val_loss: 0.2035 - val_categorical_accuracy: 0.9545
# Epoch 168/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1387 - categorical_accuracy: 0.9640 - val_loss: 0.2044 - val_categorical_accuracy: 0.9545
# Epoch 169/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1420 - categorical_accuracy: 0.9602 - val_loss: 0.2017 - val_categorical_accuracy: 0.9545
# Epoch 170/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1274 - categorical_accuracy: 0.9602 - val_loss: 0.1994 - val_categorical_accuracy: 0.9545
# Epoch 171/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1337 - categorical_accuracy: 0.9621 - val_loss: 0.2006 - val_categorical_accuracy: 0.9602
# Epoch 172/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1392 - categorical_accuracy: 0.9621 - val_loss: 0.2029 - val_categorical_accuracy: 0.9602
# Epoch 173/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1289 - categorical_accuracy: 0.9659 - val_loss: 0.2054 - val_categorical_accuracy: 0.9602
# Epoch 174/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1291 - categorical_accuracy: 0.9640 - val_loss: 0.2074 - val_categorical_accuracy: 0.9602
# Epoch 175/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1315 - categorical_accuracy: 0.9640 - val_loss: 0.2045 - val_categorical_accuracy: 0.9545
# Epoch 176/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1415 - categorical_accuracy: 0.9545 - val_loss: 0.2071 - val_categorical_accuracy: 0.9545
# Epoch 177/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1307 - categorical_accuracy: 0.9602 - val_loss: 0.2106 - val_categorical_accuracy: 0.9545
# Epoch 178/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1326 - categorical_accuracy: 0.9602 - val_loss: 0.2067 - val_categorical_accuracy: 0.9545
# Epoch 179/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1214 - categorical_accuracy: 0.9602 - val_loss: 0.2103 - val_categorical_accuracy: 0.9602
# Epoch 180/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1408 - categorical_accuracy: 0.9564 - val_loss: 0.2116 - val_categorical_accuracy: 0.9545
# Epoch 181/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1090 - categorical_accuracy: 0.9697 - val_loss: 0.2067 - val_categorical_accuracy: 0.9602
# Epoch 182/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1440 - categorical_accuracy: 0.9527 - val_loss: 0.2032 - val_categorical_accuracy: 0.9545
# Epoch 183/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1299 - categorical_accuracy: 0.9621 - val_loss: 0.2017 - val_categorical_accuracy: 0.9545
# Epoch 184/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1380 - categorical_accuracy: 0.9678 - val_loss: 0.2060 - val_categorical_accuracy: 0.9602
# Epoch 185/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1224 - categorical_accuracy: 0.9678 - val_loss: 0.2007 - val_categorical_accuracy: 0.9602
# Epoch 186/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1158 - categorical_accuracy: 0.9640 - val_loss: 0.2031 - val_categorical_accuracy: 0.9602
# Epoch 187/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1286 - categorical_accuracy: 0.9716 - val_loss: 0.2042 - val_categorical_accuracy: 0.9545
# Epoch 188/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1165 - categorical_accuracy: 0.9640 - val_loss: 0.2057 - val_categorical_accuracy: 0.9602
# Epoch 189/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1332 - categorical_accuracy: 0.9583 - val_loss: 0.2088 - val_categorical_accuracy: 0.9602
# Epoch 190/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1339 - categorical_accuracy: 0.9564 - val_loss: 0.2048 - val_categorical_accuracy: 0.9545
# Epoch 191/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1128 - categorical_accuracy: 0.9716 - val_loss: 0.2023 - val_categorical_accuracy: 0.9602
# Epoch 192/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1178 - categorical_accuracy: 0.9621 - val_loss: 0.2040 - val_categorical_accuracy: 0.9602
# Epoch 193/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1243 - categorical_accuracy: 0.9602 - val_loss: 0.2055 - val_categorical_accuracy: 0.9602
# Epoch 194/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1089 - categorical_accuracy: 0.9640 - val_loss: 0.2094 - val_categorical_accuracy: 0.9602
# Epoch 195/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1255 - categorical_accuracy: 0.9659 - val_loss: 0.2115 - val_categorical_accuracy: 0.9602
# Epoch 196/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1321 - categorical_accuracy: 0.9621 - val_loss: 0.2071 - val_categorical_accuracy: 0.9545
# Epoch 197/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1173 - categorical_accuracy: 0.9621 - val_loss: 0.2020 - val_categorical_accuracy: 0.9545
# Epoch 198/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1294 - categorical_accuracy: 0.9640 - val_loss: 0.2026 - val_categorical_accuracy: 0.9545
# Epoch 199/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1170 - categorical_accuracy: 0.9640 - val_loss: 0.2077 - val_categorical_accuracy: 0.9602
# Epoch 200/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1243 - categorical_accuracy: 0.9602 - val_loss: 0.2072 - val_categorical_accuracy: 0.9545
# Epoch 201/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1262 - categorical_accuracy: 0.9678 - val_loss: 0.2007 - val_categorical_accuracy: 0.9545
# Epoch 202/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1106 - categorical_accuracy: 0.9697 - val_loss: 0.2009 - val_categorical_accuracy: 0.9545
# Epoch 203/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1052 - categorical_accuracy: 0.9773 - val_loss: 0.2049 - val_categorical_accuracy: 0.9602
# Epoch 204/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1253 - categorical_accuracy: 0.9640 - val_loss: 0.2047 - val_categorical_accuracy: 0.9602
# Epoch 205/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1262 - categorical_accuracy: 0.9545 - val_loss: 0.2003 - val_categorical_accuracy: 0.9602
# Epoch 206/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1283 - categorical_accuracy: 0.9678 - val_loss: 0.2044 - val_categorical_accuracy: 0.9602
# Epoch 207/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1301 - categorical_accuracy: 0.9602 - val_loss: 0.2075 - val_categorical_accuracy: 0.9602
# Epoch 208/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1258 - categorical_accuracy: 0.9602 - val_loss: 0.2065 - val_categorical_accuracy: 0.9545
# Epoch 209/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1312 - categorical_accuracy: 0.9621 - val_loss: 0.2069 - val_categorical_accuracy: 0.9545
# Epoch 210/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1168 - categorical_accuracy: 0.9640 - val_loss: 0.2114 - val_categorical_accuracy: 0.9602
# Epoch 211/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1096 - categorical_accuracy: 0.9754 - val_loss: 0.2068 - val_categorical_accuracy: 0.9545
# Epoch 212/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1116 - categorical_accuracy: 0.9716 - val_loss: 0.2054 - val_categorical_accuracy: 0.9545
# Epoch 213/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1169 - categorical_accuracy: 0.9640 - val_loss: 0.2043 - val_categorical_accuracy: 0.9602
# Epoch 214/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1121 - categorical_accuracy: 0.9678 - val_loss: 0.2037 - val_categorical_accuracy: 0.9602
# Epoch 215/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1207 - categorical_accuracy: 0.9583 - val_loss: 0.2049 - val_categorical_accuracy: 0.9545
# Epoch 216/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1241 - categorical_accuracy: 0.9602 - val_loss: 0.2017 - val_categorical_accuracy: 0.9602
# Epoch 217/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1094 - categorical_accuracy: 0.9716 - val_loss: 0.2019 - val_categorical_accuracy: 0.9602
# Epoch 218/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1179 - categorical_accuracy: 0.9621 - val_loss: 0.1978 - val_categorical_accuracy: 0.9602
# Epoch 219/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1116 - categorical_accuracy: 0.9640 - val_loss: 0.2038 - val_categorical_accuracy: 0.9602
# Epoch 220/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1056 - categorical_accuracy: 0.9697 - val_loss: 0.2058 - val_categorical_accuracy: 0.9602
# Epoch 221/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1176 - categorical_accuracy: 0.9659 - val_loss: 0.2072 - val_categorical_accuracy: 0.9602
# Epoch 222/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1129 - categorical_accuracy: 0.9697 - val_loss: 0.2086 - val_categorical_accuracy: 0.9602
# Epoch 223/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1079 - categorical_accuracy: 0.9735 - val_loss: 0.2084 - val_categorical_accuracy: 0.9602
# Epoch 224/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1081 - categorical_accuracy: 0.9640 - val_loss: 0.2069 - val_categorical_accuracy: 0.9602
# Epoch 225/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1189 - categorical_accuracy: 0.9697 - val_loss: 0.2082 - val_categorical_accuracy: 0.9545
# Epoch 226/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1186 - categorical_accuracy: 0.9621 - val_loss: 0.2058 - val_categorical_accuracy: 0.9545
# Epoch 227/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0952 - categorical_accuracy: 0.9754 - val_loss: 0.2066 - val_categorical_accuracy: 0.9602
# Epoch 228/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1214 - categorical_accuracy: 0.9640 - val_loss: 0.2071 - val_categorical_accuracy: 0.9602
# Epoch 229/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1176 - categorical_accuracy: 0.9621 - val_loss: 0.2086 - val_categorical_accuracy: 0.9545
# Epoch 230/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1063 - categorical_accuracy: 0.9697 - val_loss: 0.2083 - val_categorical_accuracy: 0.9602
# Epoch 231/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1150 - categorical_accuracy: 0.9640 - val_loss: 0.2057 - val_categorical_accuracy: 0.9602
# Epoch 232/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1115 - categorical_accuracy: 0.9640 - val_loss: 0.2039 - val_categorical_accuracy: 0.9602
# Epoch 233/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1180 - categorical_accuracy: 0.9659 - val_loss: 0.2029 - val_categorical_accuracy: 0.9602
# Epoch 234/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0998 - categorical_accuracy: 0.9678 - val_loss: 0.2037 - val_categorical_accuracy: 0.9602
# Epoch 235/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1083 - categorical_accuracy: 0.9697 - val_loss: 0.2033 - val_categorical_accuracy: 0.9602
# Epoch 236/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1214 - categorical_accuracy: 0.9640 - val_loss: 0.2074 - val_categorical_accuracy: 0.9602
# Epoch 237/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0982 - categorical_accuracy: 0.9716 - val_loss: 0.2057 - val_categorical_accuracy: 0.9545
# Epoch 238/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1101 - categorical_accuracy: 0.9716 - val_loss: 0.2053 - val_categorical_accuracy: 0.9545
# Epoch 239/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1005 - categorical_accuracy: 0.9716 - val_loss: 0.2031 - val_categorical_accuracy: 0.9602
# Epoch 240/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1122 - categorical_accuracy: 0.9697 - val_loss: 0.2043 - val_categorical_accuracy: 0.9602
# Epoch 241/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1165 - categorical_accuracy: 0.9602 - val_loss: 0.2055 - val_categorical_accuracy: 0.9602
# Epoch 242/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1119 - categorical_accuracy: 0.9678 - val_loss: 0.2052 - val_categorical_accuracy: 0.9602
# Epoch 243/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1048 - categorical_accuracy: 0.9659 - val_loss: 0.2038 - val_categorical_accuracy: 0.9602
# Epoch 244/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1182 - categorical_accuracy: 0.9659 - val_loss: 0.2051 - val_categorical_accuracy: 0.9545
# Epoch 245/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1049 - categorical_accuracy: 0.9697 - val_loss: 0.2061 - val_categorical_accuracy: 0.9545
# Epoch 246/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1102 - categorical_accuracy: 0.9640 - val_loss: 0.2063 - val_categorical_accuracy: 0.9545
# Epoch 247/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1106 - categorical_accuracy: 0.9640 - val_loss: 0.2080 - val_categorical_accuracy: 0.9602
# Epoch 248/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1105 - categorical_accuracy: 0.9697 - val_loss: 0.2023 - val_categorical_accuracy: 0.9545
# Epoch 249/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1081 - categorical_accuracy: 0.9697 - val_loss: 0.2025 - val_categorical_accuracy: 0.9602
# Epoch 250/250
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0972 - categorical_accuracy: 0.9678 - val_loss: 0.2033 - val_categorical_accuracy: 0.9545

# %% [markdown]
# ## Performance metrics

# %%
print("*****    PERFORMANCE METRICS    ***** ")
print(" MAX VAL ACCURACY: " + str(max(history.history['val_categorical_accuracy'])))
print("            EPOCH: " + str(history.history['val_categorical_accuracy'].index(max(history.history['val_categorical_accuracy'])) +1))
print("     MIN VAL LOSS: " + str(min(history.history['val_loss'])))
print("            EPOCH: " + str(history.history['val_loss'].index(min(history.history['val_loss'])) +1))
# Out:
# *****    PERFORMANCE METRICS    *****
#  MAX VAL ACCURACY: 0.9602272510528564
#             EPOCH: 141
#      MIN VAL LOSS: 0.197831928730011
#             EPOCH: 218

# %% [markdown]
# ## Visualise accuracy and loss curves

# %%
# Plot the validation and training curves separately
def plot_loss_curves(history_object):
    """
    Returns separate loss curves for training and validation datasets.
    """

    loss = history_object.history['loss']
    val_loss = history_object.history['val_loss']
    accuracy = history_object.history['categorical_accuracy']
    val_accuracy = history_object.history['val_categorical_accuracy']
    epochs = range(len(history_object.history['loss']))

    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
    fig.suptitle("Loss and Accuracy Training Curves")
    fig.subplots_adjust(left=0.05)
    fig.subplots_adjust(right=0.95)

    # plot loss
    ax[0].plot(epochs, loss, label='training_loss')
    ax[0].plot(epochs, val_loss, label='val_loss')
    ax[0].set_title('Loss')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel("Loss Value")
    ax[0].legend()

    # plot accuracy
    ax[1].plot(epochs, accuracy, label='training_cat_accuracy')
    ax[1].plot(epochs, val_accuracy, label='val_cat_accuracy')
    ax[1].set_title('Accuracy')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel("Accuracy Score")
    ax[1].legend()

# %%
plot_loss_curves(history)
# Out:
# <div id='05d4563f-08be-45d6-85fb-f9a20f07e9a8'></div>

# %% [markdown]
# ## Plot confusion matrix

# %%
# make predictions with NN model
y_predicted = model.predict(X_test_scaled)
y_predicted = np.argmax(y_predicted, axis=1)

# %%
matrix = confusion_matrix(y_test, y_predicted)
plot_nn_cm(conf_mat=matrix, class_names=['Standing', 'Walking', 'Jogging', 'Side-Step', 'Running'], show_normed=True)
# Store categorical accuracy for comparison to other models
nn_cat_accuracy = list(matrix.diagonal()/matrix.sum(axis=1))
# Out:
# <div id='86d0db81-78ab-4977-b1db-9d83067c1b14'></div>

# %% [markdown]
# # Conclusion

# %%
# chart up categorical accuracy score for each model in histogram
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
fig.suptitle("Categorical Accuracy - Model Comparison \n(Test Dataset)")
fig.subplots_adjust(left=0.05)
fig.subplots_adjust(right=0.95)

# plot categorical accuracy for each classifier
X_axis1 = np.arange(len(knn_cat_accuracy))
#X_axis1 = ["Standing", "Walking", "Jogging", "Side-Step", "Running"]
bar_width = 0.2
ax[0].bar(X_axis1 -0.0, knn_cat_accuracy, bar_width, label="KNN Classifier")
ax[0].bar(X_axis1 +0.2, rf_cat_accuracy, bar_width, label="Random Forest")
ax[0].bar(X_axis1 +0.4, sgd_cat_accuracy, bar_width, label="SGD classifier")
ax[0].bar(X_axis1 +0.6, nn_cat_accuracy, bar_width, label="Neural Network")

ax[0].set_title("Categorical Accuracy")
ax[0].set_ylabel("Categorical Accuracy Score")
ax[0].set_ylim([0.8, 1.025])
# TODO: SET X LABELS FOR EACH CLASS
ax[0].set_xticklabels(["", "Standing", "Walking", "Jogging", "Side-Step", "Running"])
ax[0].legend()

# plot average categorical accuracy for each classifier
X_axis2 = ['KNN', 'RF', 'SGD', 'NN']
avg_cat_accuracy = [np.mean(knn_cat_accuracy), np.mean(rf_cat_accuracy), np.mean(sgd_cat_accuracy), np.mean(nn_cat_accuracy)]
ax[1].bar(X_axis2, avg_cat_accuracy)
ax[1].set_ylim(0.9, 1.0)
ax[1].set_title("Average Categorical Accuracy")
ax[1].set_ylabel("Categorical Accuracy Score")
# Out:
# <div id='d8487c39-9086-4c3f-b80e-c07800b1693d'></div>
# C:\Users\quinc\AppData\Local\Temp\ipykernel_17920\672953210.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(["", "Standing", "Walking", "Jogging", "Side-Step", "Running"])
# Text(0, 0.5, 'Categorical Accuracy Score')

# %%
# discuss strong and weak points for each model
#   - KNN can suffer with unbalanced classes, sensitive to outliers
#   - RF pretty good straight out of the box, top performer on test set, and is generally fairly robust, not prone to over fitting, but may struggle with extreme outliers
#   - SGD being a linear model can have difficulty separating on some features, but generally has done an ok job for this experiment
#   - NN prone to over fitting in general, this is shown in the accuracy and loss curves in this experiment where the loss curves converge and the model continues to improve fitting to the test set (i allowed this to train for more epochs to demonstrate this)
#     but accuracy on test dataset was quite good

# good results on running class, mixed results on other classes

# discuss options to improve performance
#   - larger dataset
#   - further feature engineering
#   - more rigorous analysis of activity label assignment against video timetrack


# categorical accuracy probably the best metric for comparison, as false true/positive classification are less important in this study compared to that of the study such as the poisonous vs edible mushrooms, consequences are far less significant
